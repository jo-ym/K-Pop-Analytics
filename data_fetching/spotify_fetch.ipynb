# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials


sp = spotipy.Spotify(
    auth_manager=SpotifyClientCredentials(
        client_id="client_id",
        client_secret="client_secret"
    ),
    requests_timeout=5
)

# %%
import requests
import time
from typing import Callable


class ApiExecutor:
    """
    A reusable API executor with rate limiting and retry mechanism.
    """
    
    def __init__(self, requests_per_second: int = 1, max_retries: int = 3):
        """
        Initialize the executor with rate limiting and retry settings.
        
        Args:
            requests_per_second (int): Maximum allowed requests per second.
            max_retries (int): Maximum number of retries for a failed request.
        """
        self.requests_per_second = requests_per_second
        self.max_retries = max_retries
        self.__request_delay = 1 / requests_per_second
    
    def execute_request(self, api_function: Callable, *args, **kwargs):
        """
        Execute an API function with rate limiting and retries.
        
        Args:
            api_function (Callable): A function that performs the API request.
            *args: Positional arguments for the API function.
            **kwargs: Keyword arguments for the API function.
        
        Returns:
            Any: The response from the API function, or None if all retries fail.
        """
        retries = 0
        while retries <= self.max_retries:
            try:
                # Apply rate limiting
                time.sleep(self.__request_delay)
                # Execute the API function
                return api_function(*args, **kwargs)
            except requests.exceptions.HTTPError as e:
                if e.response.status_code == 429:  # Too Many Requests
                    retry_after = int(e.response.headers.get('Retry-After', 30))  # Default to 30 seconds
                    print(f"Rate limit exceeded. Retrying after {retry_after} seconds...")
                    time.sleep(retry_after)
                    retries += 1
                else:
                    print(f"HTTP error: {e}")
                    break
            except Exception as e:
                print(f"Unexpected error: {e}")
                break
        return None

# %%
executor = ApiExecutor(requests_per_second=1, max_retries=3)

# %%
import csv
import os


# Append data to CSV
def append_to_csv(file_path: str, data: dict):
    """
    Append a single row of data to the CSV file.
    
    Args:
        file_path (str): Path to the CSV file.
        data (dict): Data to append.
    """
    file_exists = os.path.isfile(file_path)
    with open(file_path, mode='a', newline='', encoding='utf-8') as file:
        writer = csv.DictWriter(file, fieldnames=data.keys())
        if not file_exists:
            writer.writeheader()  # Write header if file doesn't exist
        writer.writerow(data)

# %%
def replace_in_csv(file_path: str, data: dict, match_condition: Callable[[dict, dict], bool]):
    """
    Replace a row in the CSV file if it matches the specified condition.
    
    Args:
        file_path (str): Path to the CSV file.
        data (dict): The new data to write.
        match_condition (Callable[[dict, dict], bool]): A function that takes two dictionaries (existing row and new data) 
                                                        and returns True if the row should be replaced.
    """
    updated = False
    temp_file_path = f"{file_path}.tmp"
    
    # Ensure the file exists
    if not os.path.isfile(file_path):
        with open(file_path, mode='w', newline='', encoding='utf-8') as file:
            writer = csv.DictWriter(file, fieldnames=data.keys())
            writer.writeheader()
            writer.writerow(data)
        return
    
    # Read and replace rows
    with open(file_path, mode='r', newline='', encoding='utf-8') as file, open(temp_file_path, mode='w', newline='', encoding='utf-8') as temp_file:
        reader = csv.DictReader(file)
        writer = csv.DictWriter(temp_file, fieldnames=reader.fieldnames)
        
        writer.writeheader()
        for row in reader:
            if match_condition(row, data):
                writer.writerow(data)  # Replace the row with new data
                updated = True
            else:
                writer.writerow(row)  # Keep the original row
    
    # If no match was found, append the new data
    if not updated:
        with open(temp_file_path, mode='a', newline='', encoding='utf-8') as temp_file:
            writer = csv.DictWriter(temp_file, fieldnames=data.keys())
            writer.writerow(data)
    
    # Replace the original file with the updated file
    os.replace(temp_file_path, file_path)


def replace_or_append_rows_in_csv(
    file_path: str,
    rows: list[dict],
    match_condition: Callable[[dict, dict], bool],
    max_retries: int = 3
):
    """
    Replace or append multiple rows in the CSV file based on a matching condition.
    
    Args:
        file_path (str): Path to the CSV file.
        rows (List[dict]): A list of rows (dictionaries) to write.
        match_condition (Callable[[dict, dict], bool]): A function that takes two dictionaries 
                                                        (existing row and new data) and returns 
                                                        True if the row should be replaced.
        max_retries (int): Maximum number of retries if file access is denied.
    """
    temp_file_path = f"{file_path}.tmp"
    retries = 0

    while retries <= max_retries:
        try:
            # Ensure the file exists
            file_exists = os.path.isfile(file_path)
            existing_rows = []
            
            # Read the existing file if it exists
            if file_exists:
                with open(file_path, mode='r', newline='', encoding='utf-8') as file:
                    reader = csv.DictReader(file)
                    existing_rows = list(reader)
            
            # Create a mapping of which rows are updated
            updated_indices = set()
            for new_row in rows:
                for i, existing_row in enumerate(existing_rows):
                    if match_condition(existing_row, new_row):
                        existing_rows[i] = new_row  # Replace existing row
                        updated_indices.add(i)
                        break
                else:
                    # If no match, append as a new row
                    existing_rows.append(new_row)
            
            # Write all rows to the temporary file
            with open(temp_file_path, mode='w', newline='', encoding='utf-8') as temp_file:
                writer = csv.DictWriter(temp_file, fieldnames=rows[0].keys())
                writer.writeheader()
                writer.writerows(existing_rows)
            
            # Replace the original file with the updated file
            os.replace(temp_file_path, file_path)
            break  # Exit the loop if successful
        
        except PermissionError as e:
            retries += 1
            print(f"Permission error: {e}. Retrying {retries}/{max_retries}...")
            if retries > max_retries:
                raise e  # Reraise the exception after exhausting retries


def match_by_id_group_list_name(existing_row, new_data):
    return (existing_row['id'] == new_data['id']) & (existing_row['group_wiki_list_name'] == new_data['group_wiki_list_name'])


def match_by_id(existing_row, new_data):
    return existing_row['id'] == new_data['id']

# %%
from datetime import datetime, timezone


# Fetch artist data from Spotify
def fetch_artist(search_name: str, sp: spotipy.Spotify, market: str | None = 'KR', genre: str | None = 'k-pop', limit: int = 1) -> dict:
    """
    Search for an artist on Spotify and fetch their data.
    
    Args:
        search_name (str): Name of the artist to search.
        sp (spotipy.Spotify): Spotify client instance.
        market (str | None): Spotify market code (e.g., 'KR' for South Korea). Default is 'KR'.
        genre (str | None): Genre filter for the search. Default is 'k-pop'.
        limit (int): Number of results to fetch. Default is 1.
        
    Returns:
        dict: Artist data or None if not found.
    """
    # Combine search filters for precision
    query = f'artist:{search_name}'
    if genre:
        query += f' genre:{genre}'
    
    if market:
        results = sp.search(q=query, type='artist', limit=limit, market=market)
    else:
        results = sp.search(q=query, type='artist', limit=limit)
    if results['artists']['items']:
        artist = results['artists']['items'][0]
        return {
            'url': artist['external_urls']['spotify'],
            'followers': artist['followers'].get('total', 0),
            'genres': artist.get('genres', []),
            'id': artist['id'],
            'name': artist['name'],
            'popularity': artist['popularity'],
            'group_wiki_list_name': search_name,
            'updated_at': datetime.now(timezone.utc)
        }
    return None

# %%
import pandas as pd

group_wiki_df = pd.read_csv('./data/group_info_from_2000.csv')
group_wiki_df.head()
# Out:
#    start_year    group                                       wiki_url decade  \
# 0        2000   Chakra   https://en.wikipedia.org/wiki/Chakra_(group)  2000s
# 1        2000   Papaya   https://en.wikipedia.org/wiki/Papaya_(group)  2000s
# 2        2000       UN        https://en.wikipedia.org/wiki/UN_(band)  2000s
# 3        2001    5tion            https://en.wikipedia.org/wiki/5tion  2000s
# 4        2001  Jewelry  https://en.wikipedia.org/wiki/Jewelry_(group)  2000s
#
#    group_wiki_name  bg_start_year  bg_end_year   bg_company bg_hanja  \
# 0   Chakra_(group)         2000.0       2006.0          NaN      NaN
# 1   Papaya_(group)         2000.0          NaN          NaN      NaN
# 2        UN_(band)         2000.0       2005.0  NH Planning      NaN
# 3            5tion         2001.0          NaN          NaN      NaN
# 4  Jewelry_(group)         2001.0          NaN  Star Empire      NaN
#
#   bg_hangul                                         bg_members
# 0       NaN      ['Hwangbo', 'Bona', 'Eun', 'Ryeowon', 'Eani']
# 1       NaN  ['Kang Kyoung-ah', 'Joo Yeun-jung', 'Cho Hye-k...
# 2       NaN                                                 []
# 3       NaN  ['Il Kwon', 'Chang Woo', 'Ju Ho', 'Jun Young',...
# 4       NaN  ['Kim Ye-won', 'Baby J', 'Kim Eunjung', 'Jung ...

# %%
# Fetch artist info from spotify
artist_data_path = './data/spotify_artist_data.csv'
spotify_artist_data = pd.read_csv(artist_data_path) if os.path.isfile(artist_data_path) else None
artist_names = group_wiki_df['group'].drop_duplicates().copy()

if spotify_artist_data is not None:
    spotify_artist_data['updated_at'] = pd.to_datetime(spotify_artist_data['updated_at'])

index = 0
for artist_name in artist_names:
    index += 1
    print(f'Processing data for {artist_name} ({index} / {len(artist_names)})...')
    if spotify_artist_data is not None and 'updated_at' in spotify_artist_data and artist_name in spotify_artist_data['group_wiki_list_name'].tolist():
        artist_id = spotify_artist_data[spotify_artist_data['group_wiki_list_name'] == artist_name]['id'].iloc[0]
        same_artist_id_data = spotify_artist_data[spotify_artist_data['id'] == artist_id]
        if same_artist_id_data['updated_at'].iloc[0] >= pd.to_datetime(datetime.now(timezone.utc)) - pd.Timedelta(hours=1):
            if same_artist_id_data['group_wiki_list_name'].iloc[0] != artist_name:
                print(f"Copy same data for {artist_name} just change group wili list name...")
                artist_data = same_artist_id_data.iloc[0,:].copy().to_dict()
                artist_data['group_wiki_list_name'] = artist_name
                replace_in_csv(artist_data_path, artist_data, match_by_id_group_list_name)
            else:
                print(f"Will not be updated, because no more ago have been updated")
            continue
    
    print(f"Fetching data for {artist_name}...")
    artist_data = executor.execute_request(fetch_artist, artist_name, sp)
    if artist_data:
        replace_in_csv(artist_data_path, artist_data, match_by_id_group_list_name)
        print(f"Data for '{artist_name}' saved.")
    else:
        print(f"No data found for '{artist_name}'.")
# Out:
# Processing data for Chakra (1 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Papaya (2 / 511)...
# Fetching data for Papaya...
# No data found for 'Papaya'.
# Processing data for UN (3 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for 5tion (4 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Jewelry (5 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for jtL (6 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for K'Pop (7 / 511)...
# Fetching data for K'Pop...
# No data found for 'K'Pop'.
# Processing data for KISS (8 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for M.I.L.K (9 / 511)...
# Fetching data for M.I.L.K...
# No data found for 'M.I.L.K'.
# Processing data for Black Beat (10 / 511)...
# Fetching data for Black Beat...
# No data found for 'Black Beat'.
# Processing data for F-iV (11 / 511)...
# Fetching data for F-iV...
# No data found for 'F-iV'.
# Processing data for Isak N Jiyeon (12 / 511)...
# Fetching data for Isak N Jiyeon...
# No data found for 'Isak N Jiyeon'.
# Processing data for LUV (13 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for MC the Max (14 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Noel (15 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Shinvi (16 / 511)...
# Fetching data for Shinvi...
# No data found for 'Shinvi'.
# Processing data for Sugar (17 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Brown Eyed Soul (18 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Take (19 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for TVXQ (20 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for TRAX (21 / 511)...
# Fetching data for TRAX...
# No data found for 'TRAX'.
# Processing data for V.O.S (22 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Gavy NJ (23 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for LPG (24 / 511)...
# Fetching data for LPG...
# No data found for 'LPG'.
# Processing data for Paran (25 / 511)...
# Fetching data for Paran...
# No data found for 'Paran'.
# Processing data for SS501 (26 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Super Junior (27 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for The Grace (28 / 511)...
# Fetching data for The Grace...
# No data found for 'The Grace'.
# Processing data for 2NB (29 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Big Bang (30 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Brown Eyed Girls (31 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for SeeYa (32 / 511)...
# Fetching data for SeeYa...
# No data found for 'SeeYa'.
# Processing data for Super Junior-K.R.Y. (33 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Untouchable (34 / 511)...
# Fetching data for Untouchable...
# No data found for 'Untouchable'.
# Processing data for Baby Vox Re.V (35 / 511)...
# Fetching data for Baby Vox Re.V...
# No data found for 'Baby Vox Re.V'.
# Processing data for Black Pearl (36 / 511)...
# Fetching data for Black Pearl...
# No data found for 'Black Pearl'.
# Processing data for F.T. Island (37 / 511)...
# Fetching data for F.T. Island...
# No data found for 'F.T. Island'.
# Processing data for Girls' Generation (38 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Kara (39 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Sunny Hill (40 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Super Junior-T (41 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Supernova (42 / 511)...
# Fetching data for Supernova...
# No data found for 'Supernova'.
# Processing data for T-max (43 / 511)...
# Copy same data for T-max just change group wili list name...
# Processing data for Tritops (44 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Wonder Girls (45 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for 2AM (46 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for 2PM (47 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Davichi (48 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Miss $ (49 / 511)...
# Fetching data for Miss $...
# No data found for 'Miss $'.
# Processing data for Shinee (50 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Super Junior-H (51 / 511)...
# Fetching data for Super Junior-H...
# No data found for 'Super Junior-H'.
# Processing data for Super Junior-M (52 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for U-KISS (53 / 511)...
# Fetching data for U-KISS...
# No data found for 'U-KISS'.
# Processing data for 2NE1 (54 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for 4Minute (55 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for After School (56 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Beast (57 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for CNBLUE (58 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for f (59 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for JQT (60 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for MBLAQ (61 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Rainbow (62 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Secret (63 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for SHU-I (64 / 511)...
# Fetching data for SHU-I...
# No data found for 'SHU-I'.
# Processing data for T-ara (65 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Urban Zakapa (66 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Coed School (67 / 511)...
# Fetching data for Coed School...
# No data found for 'Coed School'.
# Processing data for DMTN (68 / 511)...
# Fetching data for DMTN...
# No data found for 'DMTN'.
# Processing data for F.Cuz (69 / 511)...
# Fetching data for F.Cuz...
# No data found for 'F.Cuz'.
# Processing data for Girl's Day (70 / 511)...
# Fetching data for Girl's Day...
# No data found for 'Girl's Day'.
# Processing data for GD & TOP (71 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for GP Basic (72 / 511)...
# Fetching data for GP Basic...
# No data found for 'GP Basic'.
# Processing data for Homme (73 / 511)...
# Fetching data for Homme...
# No data found for 'Homme'.
# Processing data for Infinite (74 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for JYJ (75 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Led Apple (76 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Miss A (77 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Nine Muses (78 / 511)...
# Fetching data for Nine Muses...
# No data found for 'Nine Muses'.
# Processing data for One Way (79 / 511)...
# Fetching data for One Way...
# No data found for 'One Way'.
# Processing data for Orange Caramel (80 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Rooftop Moonlight (81 / 511)...
# Fetching data for Rooftop Moonlight...
# No data found for 'Rooftop Moonlight'.
# Processing data for Rhythm Power (82 / 511)...
# Fetching data for Rhythm Power...
# No data found for 'Rhythm Power'.
# Processing data for Sistar (83 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Standing Egg (84 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Teen Top (85 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Touch (86 / 511)...
# Fetching data for Touch...
# No data found for 'Touch'.
# Processing data for The Boss (87 / 511)...
# Fetching data for The Boss...
# No data found for 'The Boss'.
# Processing data for ZE:A (88 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for AA (89 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Apeace (90 / 511)...
# Fetching data for Apeace...
# No data found for 'Apeace'.
# Processing data for Apink (91 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for B1A4 (92 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Blady (93 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Block B (94 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Boyfriend (95 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Brave Girls (96 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for C-REAL (97 / 511)...
# Fetching data for C-REAL...
# No data found for 'C-REAL'.
# Processing data for Chocolat (98 / 511)...
# Fetching data for Chocolat...
# No data found for 'Chocolat'.
# Processing data for Clover (99 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Dal Shabet (100 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for F-ve Dolls (101 / 511)...
# Fetching data for F-ve Dolls...
# No data found for 'F-ve Dolls'.
# Processing data for Geeks (102 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Kim Heechul & Kim Jungmo (103 / 511)...
# Fetching data for Kim Heechul & Kim Jungmo...
# No data found for 'Kim Heechul & Kim Jungmo'.
# Processing data for M.I.B (104 / 511)...
# Fetching data for M.I.B...
# No data found for 'M.I.B'.
# Processing data for Myname (105 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for N-Sonic (106 / 511)...
# Fetching data for N-Sonic...
# No data found for 'N-Sonic'.
# Processing data for N-Train (107 / 511)...
# Fetching data for N-Train...
# No data found for 'N-Train'.
# Processing data for Rania (108 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Sistar19 (109 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Stellar (110 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Super Junior-D&E (111 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Trouble Maker (112 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Ulala Session (113 / 511)...
# Fetching data for Ulala Session...
# No data found for 'Ulala Session'.
# Processing data for 100% (114 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for 15& (115 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for 24K (116 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for A.cian (117 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for A-Jax (118 / 511)...
# Fetching data for A-Jax...
# No data found for 'A-Jax'.
# Processing data for A-Prince (119 / 511)...
# Fetching data for A-Prince...
# No data found for 'A-Prince'.
# Processing data for AOA (120 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for B.A.P (121 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Big Star (122 / 511)...
# Fetching data for Big Star...
# No data found for 'Big Star'.
# Processing data for BtoB (123 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for C-Clown (124 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Crayon Pop (125 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Cross Gene (126 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for D-Unit (127 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for EvoL (128 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for EXID (129 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Exo (130 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Fiestar (131 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Gangkiz (132 / 511)...
# Fetching data for Gangkiz...
# No data found for 'Gangkiz'.
# Processing data for Girls' Generation-TTS (133 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Glam (134 / 511)...
# Fetching data for Glam...
# No data found for 'Glam'.
# Processing data for Hello Venus (135 / 511)...
# Fetching data for Hello Venus...
# No data found for 'Hello Venus'.
# Processing data for Honey G (136 / 511)...
# Fetching data for Honey G...
# No data found for 'Honey G'.
# Processing data for JJ Project (137 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Lunafly (138 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Mr.Mr. (139 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for NU'EST (140 / 511)...
# Fetching data for NU'EST...
# No data found for 'NU'EST'.
# Processing data for Phantom (141 / 511)...
# Fetching data for Phantom...
# No data found for 'Phantom'.
# Processing data for Puretty (142 / 511)...
# Fetching data for Puretty...
# No data found for 'Puretty'.
# Processing data for She'z (143 / 511)...
# Fetching data for She'z...
# No data found for 'She'z'.
# Processing data for Skarf (144 / 511)...
# Fetching data for Skarf...
# No data found for 'Skarf'.
# Processing data for Spica (145 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Sunny Days (146 / 511)...
# Fetching data for Sunny Days...
# No data found for 'Sunny Days'.
# Processing data for Tahiti (147 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Tasty (148 / 511)...
# Fetching data for Tasty...
# No data found for 'Tasty'.
# Processing data for The SeeYa (149 / 511)...
# Fetching data for The SeeYa...
# No data found for 'The SeeYa'.
# Processing data for Tiny-G (150 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Two X (151 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for VIXX (152 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Wonder Boyz (153 / 511)...
# Fetching data for Wonder Boyz...
# No data found for 'Wonder Boyz'.
# Processing data for 2Eyes (154 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for 2Yoon (155 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for 5urprise (156 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for AlphaBat (157 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for AOA Black (158 / 511)...
# Fetching data for AOA Black...
# No data found for 'AOA Black'.
# Processing data for Bestie (159 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Boys Republic (160 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for BTS (161 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for GI (162 / 511)...
# Copy same data for GI just change group wili list name...
# Processing data for History (163 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Infinite H (164 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Ladies' Code (165 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for LC9 (166 / 511)...
# Fetching data for LC9...
# No data found for 'LC9'.
# Processing data for M.Pire (167 / 511)...
# Fetching data for M.Pire...
# No data found for 'M.Pire'.
# Processing data for QBS (168 / 511)...
# Fetching data for QBS...
# No data found for 'QBS'.
# Processing data for Royal Pirates (169 / 511)...
# Fetching data for Royal Pirates...
# No data found for 'Royal Pirates'.
# Processing data for Soohyun & Hoon (170 / 511)...
# Fetching data for Soohyun & Hoon...
# No data found for 'Soohyun & Hoon'.
# Processing data for Speed (171 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for T-ara N4 (172 / 511)...
# Fetching data for T-ara N4...
# No data found for 'T-ara N4'.
# Processing data for Topp Dogg (173 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Wassup (174 / 511)...
# Fetching data for Wassup...
# No data found for 'Wassup'.
# Processing data for 2000 Won (175 / 511)...
# Fetching data for 2000 Won...
# No data found for '2000 Won'.
# Processing data for 4L (176 / 511)...
# Fetching data for 4L...
# No data found for '4L'.
# Processing data for 4Ten (177 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for AKMU (178 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Almeng (179 / 511)...
# Fetching data for Almeng...
# No data found for 'Almeng'.
# Processing data for B.I.G (180 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Badkiz (181 / 511)...
# Fetching data for Badkiz...
# No data found for 'Badkiz'.
# Processing data for Be.A (182 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Beatwin (183 / 511)...
# Fetching data for Beatwin...
# No data found for 'Beatwin'.
# Processing data for Berry Good (184 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Bigflo (185 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Bob Girls (186 / 511)...
# Fetching data for Bob Girls...
# No data found for 'Bob Girls'.
# Processing data for Bursters (187 / 511)...
# Fetching data for Bursters...
# No data found for 'Bursters'.
# Processing data for D.Holic (188 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for GD X Taeyang (189 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Got7 (190 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for HALO (191 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for HeartB (192 / 511)...
# Fetching data for HeartB...
# No data found for 'HeartB'.
# Processing data for Hi Suhyun (193 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for High4 (194 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Hotshot (195 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Infinite F (196 / 511)...
# Fetching data for Infinite F...
# No data found for 'Infinite F'.
# Processing data for JJCC (197 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Laboum (198 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Lip Service (199 / 511)...
# Fetching data for Lip Service...
# No data found for 'Lip Service'.
# Processing data for Lovelyz (200 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Madtown (201 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Mamamoo (202 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Melody Day (203 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Minx (204 / 511)...
# Fetching data for Minx...
# No data found for 'Minx'.
# Processing data for Nasty Nasty (205 / 511)...
# Fetching data for Nasty Nasty...
# No data found for 'Nasty Nasty'.
# Processing data for Play the Siren (206 / 511)...
# Fetching data for Play the Siren...
# No data found for 'Play the Siren'.
# Processing data for Red Velvet (207 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Sonamoo (208 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Strawberry Milk (209 / 511)...
# Fetching data for Strawberry Milk...
# No data found for 'Strawberry Milk'.
# Processing data for The Barberettes (210 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for The Legend (211 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for ToHeart (212 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Troy (213 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Uniq (214 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Wings (215 / 511)...
# Fetching data for Wings...
# No data found for 'Wings'.
# Processing data for Winner (216 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Year 7 Class 1 (217 / 511)...
# Fetching data for Year 7 Class 1...
# No data found for 'Year 7 Class 1'.
# Processing data for 1Punch (218 / 511)...
# Fetching data for 1Punch...
# No data found for '1Punch'.
# Processing data for April (219 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Bastarz (220 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for CLC (221 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Day6 (222 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for DIA (223 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for GFriend (224 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for IKon (225 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for MAP6 (226 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for MAS (227 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Monsta X (228 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for MyB (229 / 511)...
# Fetching data for MyB...
# No data found for 'MyB'.
# Processing data for N.Flying (230 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Oh My Girl (231 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Playback (232 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Romeo (233 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Rubber Soul (234 / 511)...
# Fetching data for Rubber Soul...
# No data found for 'Rubber Soul'.
# Processing data for Seventeen (235 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Snuper (236 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Twice (237 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Unicorn (238 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for UP10TION (239 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for VAV (240 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for VIXX LR (241 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for AOA Cream (242 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Astro (243 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Blackpink (244 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Bolbbalgan4 (245 / 511)...
# Fetching data for Bolbbalgan4...
# No data found for 'Bolbbalgan4'.
# Processing data for Boys24 (246 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for BtoB Blue (247 / 511)...
# Fetching data for BtoB Blue...
# No data found for 'BtoB Blue'.
# Processing data for CocoSori (248 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Double S 301 (249 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Exo-CBX (250 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Gugudan (251 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for I.B.I (252 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for I.O.I (253 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Imfact (254 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for KNK (255 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for MASC (256 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for MOBB (257 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Momoland (258 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for NCT (259 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for NCT U (260 / 511)...
# Copy same data for NCT U just change group wili list name...
# Processing data for NCT 127 (261 / 511)...
# Copy same data for NCT 127 just change group wili list name...
# Processing data for NCT Dream (262 / 511)...
# Copy same data for NCT Dream just change group wili list name...
# Processing data for Nine Muses A (263 / 511)...
# Fetching data for Nine Muses A...
# No data found for 'Nine Muses A'.
# Processing data for Pentagon (264 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for SF9 (265 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for The East Light (266 / 511)...
# Fetching data for The East Light...
# No data found for 'The East Light'.
# Processing data for Unnies (267 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Victon (268 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Vromance (269 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for WJSN (270 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for 14U (271 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for 3RACHA (272 / 511)...
# Fetching data for 3RACHA...
# No data found for '3RACHA'.
# Processing data for A.C.E (273 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Boy Story (274 / 511)...
# Fetching data for Boy Story...
# No data found for 'Boy Story'.
# Processing data for Busters (275 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Dreamcatcher (276 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Duetto (277 / 511)...
# Fetching data for Duetto...
# No data found for 'Duetto'.
# Processing data for Elris (278 / 511)...
# Fetching data for Elris...
# No data found for 'Elris'.
# Processing data for Favorite (279 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Golden Child (280 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Good Day (281 / 511)...
# Fetching data for Good Day...
# No data found for 'Good Day'.
# Processing data for GreatGuys (282 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for HashTag (283 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Highlight (284 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Honeyst (285 / 511)...
# Fetching data for Honeyst...
# No data found for 'Honeyst'.
# Processing data for Hyeongseop X Euiwoong (286 / 511)...
# Fetching data for Hyeongseop X Euiwoong...
# No data found for 'Hyeongseop X Euiwoong'.
# Processing data for IN2IT (287 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for IZ (288 / 511)...
# Copy same data for IZ just change group wili list name...
# Processing data for JBJ (289 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Kard (290 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Longguo & Shihyun (291 / 511)...
# Fetching data for Longguo & Shihyun...
# No data found for 'Longguo & Shihyun'.
# Processing data for M.O.N.T (292 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Mind U (293 / 511)...
# Fetching data for Mind U...
# No data found for 'Mind U'.
# Processing data for MVP (294 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for MXM (295 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Myteen (296 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for NU'EST W (297 / 511)...
# Fetching data for NU'EST W...
# No data found for 'NU'EST W'.
# Processing data for ONF (298 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for P.O.P (299 / 511)...
# Copy same data for P.O.P just change group wili list name...
# Processing data for Pristin (300 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Rainz (301 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for S.I.S (302 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Seven O'Clock (303 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for The Boyz (304 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for The Rose (305 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for TRCNG (306 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Triple H (307 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for TST (308 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Varsity (309 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Wanna One (310 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Weki Meki (311 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for A Train To Autumn (312 / 511)...
# Fetching data for A Train To Autumn...
# No data found for 'A Train To Autumn'.
# Processing data for Ateez (313 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for D-Crunch (314 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Dream Note (315 / 511)...
# Fetching data for Dream Note...
# No data found for 'Dream Note'.
# Processing data for Fromis 9 (316 / 511)...
# Copy same data for Fromis 9 just change group wili list name...
# Processing data for I-dle (317 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Girlkind (318 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Gugudan SeMiNa (319 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for GWSN (320 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Honey Popcorn (321 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Iz*One (322 / 511)...
# Copy same data for Iz*One just change group wili list name...
# Processing data for JBJ95 (323 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for K/DA (324 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Loona (325 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Maywish (326 / 511)...
# Fetching data for Maywish...
# No data found for 'Maywish'.
# Processing data for Nature (327 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for NeonPunch (328 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Noir (329 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for NTB (330 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Oh!GG (331 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Pink Fantasy (332 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Pristin V (333 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Saturday (334 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Spectrum (335 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Stray Kids (336 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Target (337 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for UNB (338 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Uni.T (339 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for W24 (340 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for We Girls (341 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for WJMK (342 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Xeno-T (343 / 511)...
# Fetching data for Xeno-T...
# No data found for 'Xeno-T'.
# Processing data for 1Team (344 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for 1the9 (345 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for 3YE (346 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for AB6IX (347 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Ariaz (348 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Argon (349 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for BDC (350 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Bvndit (351 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Cherry Bullet (352 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for CIX (353 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for D1CE (354 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for DKZ (355 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for ENOi (356 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Everglow (357 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Exo-SC (358 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Fanatics (359 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Hinapia (360 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Hoppipolla (361 / 511)...
# Fetching data for Hoppipolla...
# No data found for 'Hoppipolla'.
# Processing data for Itzy (362 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Jus2 (363 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for MustB (364 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Newkidd (365 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Oneus (366 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Onewe (367 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for OnlyOneOf (368 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Purple Rain (369 / 511)...
# Fetching data for Purple Rain...
# No data found for 'Purple Rain'.
# Processing data for Purplebeck (370 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Rocket Punch (371 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for SuperM (372 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Teen Teen (373 / 511)...
# Copy same data for Teen Teen just change group wili list name...
# Processing data for Tomorrow X Together (374 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Vanner (375 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Verivery (376 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for We in the Zone (377 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Wooseok x Kuanlin (378 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for X1 (379 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Aespa (380 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Astro – Moonbin & Sanha (381 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for B.O.Y (382 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for BAE173 (383 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Blackswan (384 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Botopass (385 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for BtoB 4U (386 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Cignature (387 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Cravity (388 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Craxy (389 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for DKB (390 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Drippin (391 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for E'Last (392 / 511)...
# Fetching data for E'Last...
# No data found for 'E'Last'.
# Processing data for Enhypen (393 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Even of Day (394 / 511)...
# Fetching data for Even of Day...
# No data found for 'Even of Day'.
# Processing data for Ghost9 (395 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for H&D (396 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Lunarsolar (397 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for MCND (398 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for NiziU (399 / 511)...
# Fetching data for NiziU...
# No data found for 'NiziU'.
# Processing data for P1Harmony (400 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Redsquare (401 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Red Velvet – Irene & Seulgi (402 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Refund Sisters (403 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Secret Number (404 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for SSAK3 (405 / 511)...
# Fetching data for SSAK3...
# No data found for 'SSAK3'.
# Processing data for STAYC (406 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for TO1 (407 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Treasure (408 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for UNVS (409 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Weeekly (410 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for WEi (411 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Wooah (412 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Billlie (413 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Blitzers (414 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for BugAboo (415 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Ciipher (416 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Epex (417 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Hot Issue (418 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Ichillin' (419 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Ive (420 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Just B (421 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Lightsum (422 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Luminous (423 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Mirae (424 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for NTX (425 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Omega X (426 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Pixy (427 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Purple Kiss (428 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for TFN (429 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for The KingDom (430 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Tri.be (431 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Xdinary Heroes (432 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for &Team (433 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Acid Angel from Asia (434 / 511)...
# Fetching data for Acid Angel from Asia...
# No data found for 'Acid Angel from Asia'.
# Processing data for Aimers (435 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Astro – Jinjin & Rocky (436 / 511)...
# Fetching data for Astro – Jinjin & Rocky...
# No data found for 'Astro – Jinjin & Rocky'.
# Processing data for ATBO (437 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Blank2y (438 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Classy (439 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for CSR (440 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Fifty Fifty (441 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Got the Beat (442 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for H1-Key (443 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for ILY:1 (444 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Irris (445 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Kep1er (446 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Lapillus (447 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Le Sserafim (448 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Mamamoo+ (449 / 511)...
# Copy same data for Mamamoo+ just change group wili list name...
# Processing data for Mimiirose (450 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for NewJeans (451 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Nmixx (452 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for TAN (453 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Tempest (454 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for The New Six (455 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Trendz (456 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Viviz (457 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for WSG Wannabe (458 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Younite (459 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for 8Turn (460 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for 82Major (461 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Ampers&One (462 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Babymonster (463 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for BoyNextDoor (464 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for BXB (465 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for El7z Up (466 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Evnne (467 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Fantasy Boys (468 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Hori7on (469 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Kiss of Life (470 / 511)...
# Copy same data for Kiss of Life just change group wili list name...
# Processing data for Loossemble (471 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Lun8 (472 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Mave: (473 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for N.SSign (474 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for NCT DoJaeJung (475 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for One Pact (476 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Plave (477 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Pow (478 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Primrose (479 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Riize (480 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Shownu X Hyungwon (481 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for The Wind (482 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for TIOT (483 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for TripleS (484 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Xikers (485 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Xodiac (486 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Young Posse (487 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Zerobaseone (488 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for AllOurs (489 / 511)...
# Fetching data for AllOurs...
# No data found for 'AllOurs'.
# Processing data for ARrC (490 / 511)...
# Fetching data for ARrC...
# No data found for 'ARrC'.
# Processing data for Artms (491 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for B.D.U (492 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Badvillain (493 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Big Ocean (494 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Candy Shop (495 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Dragon Pony (496 / 511)...
# Fetching data for Dragon Pony...
# No data found for 'Dragon Pony'.
# Processing data for Dxmon (497 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Geenius (498 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Illit (499 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Izna (500 / 511)...
# Fetching data for Izna...
# No data found for 'Izna'.
# Processing data for Madein (501 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Meovv (502 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Mytro (503 / 511)...
# Fetching data for Mytro...
# No data found for 'Mytro'.
# Processing data for NOMAD (504 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Nowadays (505 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Rescene (506 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Say My Name (507 / 511)...
# Fetching data for Say My Name...
# No data found for 'Say My Name'.
# Processing data for TWS (508 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Unis (509 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Waker (510 / 511)...
# Will not be updated, because no more ago have been updated
# Processing data for Waterfire (511 / 511)...
# Will not be updated, because no more ago have been updated

# %%
import pandas as pd

spotify_artist_data = pd.read_csv('./data/spotify_artist_data.csv')
spotify_artist_data.head()
# Out:
#                                                  url  followers  \
# 0  https://open.spotify.com/artist/0yn2cFHoVqRiZO...          6
# 1  https://open.spotify.com/artist/0jhgI3xU8n2o1W...      12572
# 2  https://open.spotify.com/artist/6MJCgDOw7EfTJJ...       2068
# 3  https://open.spotify.com/artist/01iyQzyns6Ab0L...       7688
# 4  https://open.spotify.com/artist/1QxDhdpQDAxevR...       9118
#
#                            genres                      id             name  \
# 0         ['classic konkani pop']  0yn2cFHoVqRiZOgkVs58Uc  Deb Chakravarty
# 1  ['k-indie', 'korean city pop']  0jhgI3xU8n2o1W6EOw9dIf     Light & Salt
# 2             ['k-pop boy group']  6MJCgDOw7EfTJJtKPHXAcD            5tion
# 3               ['classic k-pop']  01iyQzyns6Ab0LxjYvHcg9          Jewelry
# 4      ['classic k-pop', 'k-rap']  1QxDhdpQDAxevRaOWUDjPC              JTL
#
#    popularity group_wiki_list_name                        updated_at
# 0           0               Chakra  2024-12-04 11:49:38.034351+00:00
# 1          30                   UN  2024-12-04 11:49:40.147774+00:00
# 2          10                5tion  2024-12-04 11:49:41.219361+00:00
# 3          10              Jewelry  2024-12-04 11:49:42.297991+00:00
# 4          30                  jtL  2024-12-04 11:49:43.379053+00:00

# %%
def fetch_artist_albums(
    artist_id: str,
    sp: spotipy.Spotify,
    executor: ApiExecutor,
    include_groups: list[str] = ['single', 'album'],
    limit: int = 20,
    album_data_path: str = 'artist_albums.csv'
) -> pd.DataFrame:
    """
    Fetch all albums of an artist using Spotify API.
    
    Args:
        artist_id (str): Spotify artist ID.
        sp (spotipy.Spotify): Spotify client instance.
        executor (ApiExecutor): API executor for rate limiting and retries.
        include_groups (list): Album types to include, default ['single', 'album'].
        limit (int): Number of results to fetch per API call, default is 20.
        album_data_path (str): Filepath for saving results, default 'artist_albums.csv'.
    
    Returns:
        pd.DataFrame: Combined DataFrame of all album data.
    """
    offset = 0
    all_albums = []
    processed_album_ids = set()
    total_albums = 0
    new_albums_count = 0  # Track number of new albums added
    
    # Load existing CSV data to avoid duplicates
    try:
        existing_albums = pd.read_csv(album_data_path)
        processed_album_ids = set(existing_albums['id'])
        total_albums = len(existing_albums)
        print(f"Loaded existing data with {len(processed_album_ids)} albums.")
    except FileNotFoundError:
        print("No existing album data found. Starting fresh.")
    
    while True:
        try:
            # Prepare parameters for the API request
            params = {
                'include_groups': ','.join(include_groups),
                'limit': limit,
                'offset': offset
            }
            
            # Execute API request with rate limiting and retries
            response = executor.execute_request(
                lambda: sp.artist_albums(artist_id, **params)
            )
            
            albums = response.get('items', [])
            api_total = response.get('total', 0)
            next_page = response.get('next', None)
            
            if api_total == total_albums:
                print("No new albums detected. Skipping fetch.")
                break
            
            if not albums:
                print("No more albums to fetch.")
                break  # Exit the loop if no more results
            
            for album in albums:
                if album['id'] in processed_album_ids:
                    continue  # Skip already processed albums
                
                # Extract album data
                album_data = {
                    'url': album['external_urls'].get('spotify'),
                    'id': album['id'],
                    'name': album['name'],
                    'album_type': album['album_type'],
                    'total_tracks': album['total_tracks'],
                    'available_markets': album['available_markets'],
                    'release_date': album['release_date'],
                    'release_date_precision': album['release_date_precision'],
                    'artist_id': artist_id,
                    'updated_at': datetime.now(timezone.utc)
                }
                all_albums.append(album_data)
                processed_album_ids.add(album['id'])
                new_albums_count += 1  # Increment new albums count
                
                # Save album data to CSV immediately
                append_to_csv(album_data_path, album_data)
                
            print(f"Fetched {len(albums)} albums (offset: {offset}).")
            if not next_page:
                print("No next page available. Stopping fetch.")
                break
            
            offset += limit
        
        except Exception as e:
            print(f"Error fetching albums for artist {artist_id} at offset {offset}: {e}")
            break
    
    # Print the number of new albums added
    print(f"Finished fetching albums. Added {new_albums_count} new albums.")
    
    # Convert all albums to DataFrame and return
    albums_df = pd.DataFrame(all_albums)
    return albums_df

# %%
all_albums_df = pd.DataFrame()
executor.requests_per_second = 0.7 # Because the amount of data is relatively large, the required speed is reduced
filtered_spotify_artist_data = spotify_artist_data.drop_duplicates('id', keep='first')
for index, row in spotify_artist_data.iterrows():
    artist_id = row['id']
    artist_name = row['name']
    print(f'Feching {artist_name} ({artist_id}) albums ({index + 1}/{len(spotify_artist_data)})...')
    
    album_data_path = os.path.join(
        './data/albums',
        f'{artist_id}.csv'
    )
    albums_df = fetch_artist_albums(
        artist_id=artist_id,
        sp=sp,
        executor=executor,
        include_groups=['single', 'album'],
        album_data_path=album_data_path
    )
    all_albums_df = pd.concat([all_albums_df, albums_df])

all_albums_df
# Out:
# Feching Deb Chakravarty (0yn2cFHoVqRiZOgkVs58Uc) albums (1/394)...
# No existing album data found. Starting fresh.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Light & Salt (0jhgI3xU8n2o1W6EOw9dIf) albums (2/394)...
# Loaded existing data with 15 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching 5tion (6MJCgDOw7EfTJJtKPHXAcD) albums (3/394)...
# Loaded existing data with 22 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Jewelry (01iyQzyns6Ab0LxjYvHcg9) albums (4/394)...
# Loaded existing data with 7 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching JTL (1QxDhdpQDAxevRaOWUDjPC) albums (5/394)...
# Loaded existing data with 5 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching KISS OF LIFE (4TEK9tIkcoxib4GxT3O4ky) albums (6/394)...
# Loaded existing data with 9 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Helly Luv (0lBdxuK0H39asKRIUxLzhm) albums (7/394)...
# Loaded existing data with 12 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching M.C the Max (3MaRWfwKpbYnkYHC5gRKYo) albums (8/394)...
# Loaded existing data with 32 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Noel (2G5VFTwwlZUulCbtPbc1nx) albums (9/394)...
# Loaded existing data with 45 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Sugarbowl (0SzEYg3WelMs62HakSDhPH) albums (10/394)...
# Loaded existing data with 21 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching BROWN EYED SOUL (7AVa6rcpTQWVqgy91llPP5) albums (11/394)...
# Loaded existing data with 16 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Mariya Takeuchi (3WwGRA2o4Ux1RRMYaYDh7N) albums (12/394)...
# Loaded existing data with 8 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching TVXQ! (6nVMMEywS5Y4tsHPKx1nIo) albums (13/394)...
# Loaded existing data with 46 albums.
# Fetched 20 albums (offset: 0).
# Fetched 7 albums (offset: 20).
# Fetched 19 albums (offset: 40).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching V.O.S (2x8nGCQ6zMQYA8oAX6Ggk2) albums (14/394)...
# Loaded existing data with 31 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Gavy NJ (6Iyc2IvCGBNStXUmPa8hmu) albums (15/394)...
# Loaded existing data with 49 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching SS501 (6rmMpoeu2SIV4OLURCOn2e) albums (16/394)...
# Loaded existing data with 27 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching SUPER JUNIOR (6gzXCdfYfFe5XKhPKkYqxV) albums (17/394)...
# Loaded existing data with 35 albums.
# Fetched 20 albums (offset: 0).
# Fetched 6 albums (offset: 20).
# Fetched 9 albums (offset: 40).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching 2NB (01n1Lj2lmdteXD8qFPqhsL) albums (18/394)...
# Loaded existing data with 55 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching BIGBANG (4Kxlr1PRlDKEB0ekOCyHgX) albums (19/394)...
# Loaded existing data with 29 albums.
# Fetched 20 albums (offset: 0).
# Fetched 1 albums (offset: 20).
# Fetched 8 albums (offset: 40).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Brown Eyed Girls (2GEPtT5RDxrmdi0A4mbDi7) albums (20/394)...
# Loaded existing data with 23 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching SUPER JUNIOR-K.R.Y. (5Kdp1Iq26eCz7XbPxOgt7F) albums (21/394)...
# Loaded existing data with 7 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Girls' Generation (0Sadg1vgvaPqGTOjxu0N6c) albums (22/394)...
# Loaded existing data with 24 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Hwang Karam (61jr8e2uLQusD1PLqTKqQc) albums (23/394)...
# Loaded existing data with 35 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Sunny Hill (1ePYD8tMMM4Y8gbwi69vaf) albums (24/394)...
# Loaded existing data with 33 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching SUPER JUNIOR-T (5Z595Kh9tlzZuyneUHI111) albums (25/394)...
# Loaded existing data with 2 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching M.C the Max (3MaRWfwKpbYnkYHC5gRKYo) albums (26/394)...
# Loaded existing data with 32 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Tritops (2GodMITO0T7cejkGnenP05) albums (27/394)...
# Loaded existing data with 16 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Wonder Girls (3Cv2vi3WTl8VZOTdrBkKdM) albums (28/394)...
# Loaded existing data with 16 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching 2AM (5SnaL8SsjGMHQNyqpa8Zos) albums (29/394)...
# Loaded existing data with 20 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching 2PM (5iRPbkcPmqAFFwDUj6ywVS) albums (30/394)...
# Loaded existing data with 41 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching DAVICHI (4z6yrDz5GfKXkeQZjOaZdq) albums (31/394)...
# Loaded existing data with 65 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching SHINee (2hRQKC0gqlZGPrmUKbcchR) albums (32/394)...
# Loaded existing data with 26 albums.
# Fetched 20 albums (offset: 0).
# Fetched 4 albums (offset: 20).
# Fetched 2 albums (offset: 40).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching SUPER JUNIOR-M (4yNdRuMECm7sFnAOQ6MieS) albums (33/394)...
# Loaded existing data with 8 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching 2NE1 (1l0mKo96Jh9HVYONcRl3Yp) albums (34/394)...
# Loaded existing data with 20 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching 4Minute (6cdC1cwqh3eJAXaxXJt2jv) albums (35/394)...
# Loaded existing data with 24 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching After School (1loWI8jVk9btgJXHgqHXPD) albums (36/394)...
# Loaded existing data with 17 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Beast (1Pr9gT0veB2tgcisQeIGoC) albums (37/394)...
# Loaded existing data with 38 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching CNBLUE (6dCz3spfpIvqqqsIoP6wXi) albums (38/394)...
# Loaded existing data with 49 albums.
# Fetched 20 albums (offset: 0).
# Fetched 12 albums (offset: 20).
# Fetched 17 albums (offset: 40).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching fromis_9 (24nUVBIlCGi4twz4nYxJum) albums (39/394)...
# Loaded existing data with 17 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching JQT (6ManwBDLto2d2jMmGM0Gln) albums (40/394)...
# Loaded existing data with 2 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching MBLAQ (14f1WN9TUDVBK4sHUStmLG) albums (41/394)...
# Loaded existing data with 23 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching RAINBOW (7xDyxRXgFgOZhdtLtkYR1y) albums (42/394)...
# Loaded existing data with 19 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Secret (503DjcVO5Ku1NgLPhVuNg7) albums (43/394)...
# Loaded existing data with 18 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching T-ARA (1R52cwGf75yTf7I3Q0Irf8) albums (44/394)...
# Loaded existing data with 39 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Urban Zakapa (1dOMFM5wDNsENQQW0nl0K8) albums (45/394)...
# Loaded existing data with 33 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching GD&TOP (3e3oLJehq4vQl2H0FAJnvn) albums (46/394)...
# Loaded existing data with 2 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching INFINITE (1bkpTEmumLC3xc7HgMsttU) albums (47/394)...
# Loaded existing data with 35 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching JYJ (23pnZUOyyTzYzg5GZSvj4Y) albums (48/394)...
# Loaded existing data with 5 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Ledapple (4PhwZL3iuVNfhh8mza8pqD) albums (49/394)...
# Loaded existing data with 12 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching miss A (1BEohdSWSBggmO979tzRwW) albums (50/394)...
# Loaded existing data with 8 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Orange Caramel (2QHTtUsN6Q13w3QHdfRqsK) albums (51/394)...
# Loaded existing data with 12 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching SISTAR (2wTLheTmMcFCA4hdY8hZJP) albums (52/394)...
# Loaded existing data with 15 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Standing Egg (6a3Mfrn2XBR1DfPg1QGa1d) albums (53/394)...
# Loaded existing data with 86 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching TEEN TOP (3offPqpKAKmpQkIdWnjzkc) albums (54/394)...
# Loaded existing data with 26 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching ZE:A (6lGfLCig2b5mvDTtsPSrb0) albums (55/394)...
# Loaded existing data with 21 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Aashish Yadav (6Q7zxRpatEpouz1e7dLbsG) albums (56/394)...
# Loaded existing data with 687 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Apink (2uWcrwgWmZcQc3IPBs3tfU) albums (57/394)...
# Loaded existing data with 35 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching B1A4 (3sxWOFw4MSN54SIQ8np6iG) albums (58/394)...
# Loaded existing data with 37 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Blady (1Aecez8YftwSagjHkL1vuA) albums (59/394)...
# Loaded existing data with 2 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Block B (4RnezwRV7VBJUCI1S0AE5u) albums (60/394)...
# Loaded existing data with 17 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching BOYFRIEND (2Pw8E6zZoeuksVWtyZPnzd) albums (61/394)...
# Loaded existing data with 21 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Brave Girls (7t5H3uQv0Zw6cQUnSTF5BB) albums (62/394)...
# Loaded existing data with 20 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Momoiro Clover Z (3Zl0EsuYV23OgNw6WqGelN) albums (63/394)...
# Loaded existing data with 56 albums.
# Fetched 20 albums (offset: 0).
# Fetched 1 albums (offset: 20).
# Fetched 20 albums (offset: 40).
# Fetched 15 albums (offset: 60).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Dalshabet (10xsuRNvidaOLxWd3fRIel) albums (64/394)...
# Loaded existing data with 9 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Geeks (5VxfguafjfSdJcN10ACVZe) albums (65/394)...
# Loaded existing data with 20 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching MYNAME (1Q8ON7PhIGhFtgbfzx13CK) albums (66/394)...
# Loaded existing data with 13 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Rania (5sUKi0QlHVxvsCzmrhJsFO) albums (67/394)...
# Loaded existing data with 8 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching SISTAR19 (5Q0U6ogBrMX2oxmxy5OTzU) albums (68/394)...
# Loaded existing data with 3 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Stellar (1rTwKjYcA7diHAD2c8ZozT) albums (69/394)...
# Loaded existing data with 5 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching SUPER JUNIOR-D&E (3EfnKIG9827OXkcQQT7HEI) albums (70/394)...
# Loaded existing data with 30 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Trouble Maker (0ztjVBmFk6OuHq6XBBwMI9) albums (71/394)...
# Loaded existing data with 3 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching 100% (3fkFO5lmipe654caBLBD6n) albums (72/394)...
# Loaded existing data with 17 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching 15& (1AAJLswvl7anW1RhTTFzxN) albums (73/394)...
# Loaded existing data with 5 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Meezy24k (20tqlItbnxGezRWiwIxzsz) albums (74/394)...
# Loaded existing data with 4 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching A.cian (에이션) (54kFWyVNZETwrt78EUjGA1) albums (75/394)...
# Loaded existing data with 1 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching AOA (54gWVQFHf8IIqbjxAoOarN) albums (76/394)...
# Loaded existing data with 20 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching B.A.P (6kxCoNfY6U1eP0Yc88phvk) albums (77/394)...
# Loaded existing data with 22 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching BTOB (2hcsKca6hCfFMwwdbFvenJ) albums (78/394)...
# Loaded existing data with 46 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Mad Clown (0dX6tgZKWpamoFHFuXFhwd) albums (79/394)...
# Loaded existing data with 29 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Crayon Pop (0ODX6aegsZkBmBeMA5qqwi) albums (80/394)...
# Loaded existing data with 12 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching CROSS GENE (5xKVZmAj8EnT9X9Acz1Qvv) albums (81/394)...
# Loaded existing data with 15 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching D-UNIT (4d2BqbEdAXBlWjgcMacPlq) albums (82/394)...
# Loaded existing data with 6 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Evol (3ACbVQlfUaW0Qm2DDe5T18) albums (83/394)...
# Loaded existing data with 3 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching EXID (1xs6WFotNQSXweo0GXrS0O) albums (84/394)...
# Loaded existing data with 24 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching EXO (3cjEqqelV9zb4BYE3qDQ4O) albums (85/394)...
# Loaded existing data with 35 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching FIESTAR (3IVjXrnR0npv1LY24kQSzd) albums (86/394)...
# Loaded existing data with 13 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Girls' Generation-TTS (7AKHnZVqwXYuUwWJ8UGL5q) albums (87/394)...
# Loaded existing data with 3 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching JJ Project (0yvw5zYym2ZnM2vngHvfWW) albums (88/394)...
# Loaded existing data with 2 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Lunafly (1qJxTCQsqd1TUMKefuzeM7) albums (89/394)...
# Loaded existing data with 12 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Charanraj MR (002yVW3Yn595KWy74buQ1k) albums (90/394)...
# Loaded existing data with 115 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Spica (73KMbnxZVe8VaUzS5yYTyg) albums (91/394)...
# Loaded existing data with 9 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Tahiti (1Y02Ts0nV3DTziLQZYVX4V) albums (92/394)...
# Loaded existing data with 9 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Tiny G (2ZyXV9Jxa7AGyQdWZE2jeN) albums (93/394)...
# Loaded existing data with 4 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Two X (0lsdeCM6sZmfdJFQ5i5pWT) albums (94/394)...
# Loaded existing data with 2 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching VIXX (5BkB3rXc0qIdUtuEnhbK0A) albums (95/394)...
# Loaded existing data with 30 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching 2EYES (4LJbolSjae2xrHVYL5WrAl) albums (96/394)...
# Loaded existing data with 2 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching 2Yoon (0TZwYeCBGsOjdJXyFLNuaa) albums (97/394)...
# Loaded existing data with 1 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching 5urprise (5q9BdeESGfyu6iVrGPhhj3) albums (98/394)...
# No existing album data found. Starting fresh.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching AlphaBAT (6Sraqxmu4WQ8YUhwqk3skW) albums (99/394)...
# Loaded existing data with 7 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching BESTie (1HiZjIv6iLp9cs5vX0AJKo) albums (100/394)...
# Loaded existing data with 8 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Boys Republic (0iLbcXKdKfMdqllxqSUhPn) albums (101/394)...
# Loaded existing data with 16 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching BTS (3Nrfpe0tUJi4K4DXYWgMUX) albums (102/394)...
# Loaded existing data with 60 albums.
# Fetched 20 albums (offset: 0).
# Fetched 1 albums (offset: 20).
# Fetched 20 albums (offset: 40).
# Fetched 19 albums (offset: 60).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Girls' Generation (0Sadg1vgvaPqGTOjxu0N6c) albums (103/394)...
# Loaded existing data with 24 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching HISTORY (08JUr2CwqQou19WWRqScKX) albums (104/394)...
# Loaded existing data with 6 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching INFINITE H (6wG0oxTnYjwcjpdK3YRtR1) albums (105/394)...
# Loaded existing data with 2 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching LADIES' CODE (4epPY1AW9lQeVUM1XaFiwi) albums (106/394)...
# Loaded existing data with 13 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching SPEED (3IMT3Xwi7qf8d5bxBeZ9bU) albums (107/394)...
# Loaded existing data with 7 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching ToppDogg (03Ejz4OkKzGnTRKZE3KwRN) albums (108/394)...
# Loaded existing data with 10 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching 4TEN (6XTJcgSOtX7zGavi7EOazp) albums (109/394)...
# Loaded existing data with 1 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching AKMU (6OwKE9Ez6ALxpTaKcT5ayv) albums (110/394)...
# Loaded existing data with 19 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching B.I.G (6gHyYB83BQlGKpqbn57D8R) albums (111/394)...
# Loaded existing data with 13 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Azad Bedran (6nf6LaxU7kzFoQmiWB9LFN) albums (112/394)...
# Loaded existing data with 44 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching BerryGood (2gW6OQobWMbkR1cKo72H2t) albums (113/394)...
# Loaded existing data with 15 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching BIGFLO (6sNZv2iaHAw7bAP2ZtKhvO) albums (114/394)...
# Loaded existing data with 6 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching D.Holic (1V7MmQ36ihG1f3qe46L50n) albums (115/394)...
# No existing album data found. Starting fresh.
# Fetched 4 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 4 new albums.
# Feching GD X TAEYANG (3HJVw8aEtFqoc3raJVE8am) albums (116/394)...
# No existing album data found. Starting fresh.
# Fetched 1 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 1 new albums.
# Feching GOT7 (6nfDaffa50mKtEOwR8g4df) albums (117/394)...
# No existing album data found. Starting fresh.
# Fetched 20 albums (offset: 0).
# Fetched 20 albums (offset: 20).
# Fetched 1 albums (offset: 40).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 41 new albums.
# Feching HALO (295glUeBYb1uqpNrSeYs1d) albums (118/394)...
# No existing album data found. Starting fresh.
# Fetched 15 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 15 new albums.
# Feching HI SUHYUN (6E7TbMh8kSKJBr2zA1omRB) albums (119/394)...
# No existing album data found. Starting fresh.
# Fetched 1 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 1 new albums.
# Feching HIGH4 (3cpG0SJLIJ1qpQfjmlWlzo) albums (120/394)...
# No existing album data found. Starting fresh.
# Fetched 8 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 8 new albums.
# Feching HotShot (0lE4Ctn38KnvJ56oGRkNx7) albums (121/394)...
# No existing album data found. Starting fresh.
# Fetched 7 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 7 new albums.
# Feching JJCC (3rC2q45kAmfLOAvrExJIXn) albums (122/394)...
# No existing album data found. Starting fresh.
# Fetched 6 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 6 new albums.
# Feching LABOUM (4iO5uKMUphLqQ20TfrdZx3) albums (123/394)...
# No existing album data found. Starting fresh.
# Fetched 20 albums (offset: 0).
# Fetched 1 albums (offset: 20).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 21 new albums.
# Feching Lovelyz (3g34PW5oNmDBxMVUTzx2XK) albums (124/394)...
# No existing album data found. Starting fresh.
# Fetched 20 albums (offset: 0).
# Fetched 1 albums (offset: 20).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 21 new albums.
# Feching MADTOWN (1sSdeMLtQYafYh0RxMtVQd) albums (125/394)...
# No existing album data found. Starting fresh.
# Fetched 5 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 5 new albums.
# Feching MAMAMOO (0XATRDCYuuGhk0oE7C0o5G) albums (126/394)...
# No existing album data found. Starting fresh.
# Fetched 20 albums (offset: 0).
# Fetched 20 albums (offset: 20).
# Fetched 17 albums (offset: 40).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 57 new albums.
# Feching MelodyDay (7lD3HWDgSgMxHNFno02dJp) albums (127/394)...
# No existing album data found. Starting fresh.
# Fetched 20 albums (offset: 0).
# Fetched 3 albums (offset: 20).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 23 new albums.
# Feching Red Velvet (1z4g3DjTBBZKhvAroFlhOM) albums (128/394)...
# No existing album data found. Starting fresh.
# Fetched 20 albums (offset: 0).
# Fetched 19 albums (offset: 20).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 39 new albums.
# Feching SONAMOO (2MY1GcYSTw3QH2C1Umzsq0) albums (129/394)...
# No existing album data found. Starting fresh.
# Fetched 8 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 8 new albums.
# Feching The Barberettes (6dZBjKEpZkglz4Xq5ni0eZ) albums (130/394)...
# No existing album data found. Starting fresh.
# Fetched 20 albums (offset: 0).
# Fetched 1 albums (offset: 20).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 21 new albums.
# Feching The Legend (0rZnVbGcSVME5bf8H4pLw9) albums (131/394)...
# No existing album data found. Starting fresh.
# Fetched 9 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 9 new albums.
# Feching Toheart (33bos49K745wYZoOz0caWQ) albums (132/394)...
# No existing album data found. Starting fresh.
# Fetched 2 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 2 new albums.
# Feching Troy Kingi (5B3LZw3NTEg074irKeEAom) albums (133/394)...
# No existing album data found. Starting fresh.
# Fetched 20 albums (offset: 0).
# Fetched 7 albums (offset: 20).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 27 new albums.
# Feching UNIQ (0ewnmx72rVozQtvslLl0t1) albums (134/394)...
# No existing album data found. Starting fresh.
# Fetched 2 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 2 new albums.
# Feching WINNER (5DuzBeOgFwViFcv00Q5PFb) albums (135/394)...
# No existing album data found. Starting fresh.
# Fetched 20 albums (offset: 0).
# Fetched 7 albums (offset: 20).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 27 new albums.
# Feching APRIL (4cJ99wTjC60pXcfyISL9fa) albums (136/394)...
# No existing album data found. Starting fresh.
# Fetched 17 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 17 new albums.
# Feching Block B - BASTARZ (70ptvBQye3QMlbuTKrF1qb) albums (137/394)...
# No existing album data found. Starting fresh.
# Fetched 4 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 4 new albums.
# Feching CLC (6QyO41KctzGc70mVaVnXQO) albums (138/394)...
# No existing album data found. Starting fresh.
# Fetched 16 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 16 new albums.
# Feching DAY6 (5TnQc2N1iKlFjYD7CPGvFc) albums (139/394)...
# No existing album data found. Starting fresh.
# Fetched 20 albums (offset: 0).
# Fetched 12 albums (offset: 20).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 32 new albums.
# Feching DIA (5Pcx98OUnL52aGZRRQx5v8) albums (140/394)...
# No existing album data found. Starting fresh.
# Fetched 13 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 13 new albums.
# Feching GFRIEND (0qlWcS66ohOIi0M8JZwPft) albums (141/394)...
# No existing album data found. Starting fresh.
# Fetched 16 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 16 new albums.
# Feching iKON (5qRSs6mvI17zrkJpOHkCoM) albums (142/394)...
# No existing album data found. Starting fresh.
# Fetched 20 albums (offset: 0).
# Fetched 2 albums (offset: 20).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 22 new albums.
# Feching MAP6 (55v257FGQ3UWCmBDpHFCER) albums (143/394)...
# No existing album data found. Starting fresh.
# Fetched 9 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 9 new albums.
# Feching Mashakbeen (4o0y1pj1wIGgvq2bWvamsn) albums (144/394)...
# No existing album data found. Starting fresh.
# Fetched 20 albums (offset: 0).
# Fetched 16 albums (offset: 20).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 36 new albums.
# Feching MONSTA X (4TnGh5PKbSjpYqpIdlW5nz) albums (145/394)...
# No existing album data found. Starting fresh.
# Fetched 20 albums (offset: 0).
# Fetched 20 albums (offset: 20).
# Fetched 20 albums (offset: 40).
# Fetched 4 albums (offset: 60).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 64 new albums.
# Feching N.Flying (2ZmXexIJAD7PgABrj0qQRb) albums (146/394)...
# No existing album data found. Starting fresh.
# Fetched 20 albums (offset: 0).
# Fetched 20 albums (offset: 20).
# Fetched 1 albums (offset: 40).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 41 new albums.
# Feching OH MY GIRL (2019zR22qK2RBvCqtudBaI) albums (147/394)...
# No existing album data found. Starting fresh.
# Fetched 20 albums (offset: 0).
# Fetched 20 albums (offset: 20).
# Fetched 9 albums (offset: 40).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 49 new albums.
# Feching PLAYBACK (1y2P8K8WFANJ4WKlKm35Bz) albums (148/394)...
# No existing album data found. Starting fresh.
# Fetched 4 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 4 new albums.
# Feching ROMEO (2JKXIXxhS7AYv1XzYFDlAH) albums (149/394)...
# No existing album data found. Starting fresh.
# Fetched 8 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 8 new albums.
# Feching SEVENTEEN (7nqOGRxlXj7N2JYbgNEjYH) albums (150/394)...
# No existing album data found. Starting fresh.
# Fetched 20 albums (offset: 0).
# Fetched 20 albums (offset: 20).
# Fetched 12 albums (offset: 40).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 52 new albums.
# Feching SNUPER (3RkN2CENR9zgHLKn2H3hcI) albums (151/394)...
# No existing album data found. Starting fresh.
# Fetched 20 albums (offset: 0).
# Fetched 2 albums (offset: 20).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 22 new albums.
# Feching TWICE (7n2Ycct7Beij7Dj7meI4X0) albums (152/394)...
# No existing album data found. Starting fresh.
# Fetched 20 albums (offset: 0).
# Fetched 2 albums (offset: 20).
# Fetched 20 albums (offset: 40).
# Fetched 18 albums (offset: 60).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 60 new albums.
# Feching Unicorn (1TcbgUzUz9pA3mN30ZXnHl) albums (153/394)...
# No existing album data found. Starting fresh.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching UP10TION (2LjaeuGS0ubYXZfNihGp9y) albums (154/394)...
# No existing album data found. Starting fresh.
# Fetched 20 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 20 new albums.
# Feching VAV (3riGN5iBVBk5naQxUDr5fk) albums (155/394)...
# No existing album data found. Starting fresh.
# Fetched 19 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 19 new albums.
# Feching VIXX LR (14Crgqr0bcwGyyxXSkj01S) albums (156/394)...
# No existing album data found. Starting fresh.
# Fetched 3 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 3 new albums.
# Feching AOA CREAM (1o35i8zNVhVMPgwibiHjPk) albums (157/394)...
# No existing album data found. Starting fresh.
# Fetched 1 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 1 new albums.
# Feching ASTRO (4pz4uzOMpJQyV8UTsDy4H8) albums (158/394)...
# No existing album data found. Starting fresh.
# Fetched 20 albums (offset: 0).
# Fetched 5 albums (offset: 20).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 25 new albums.
# Feching BLACKPINK (41MozSoPIsD1dJM0CLPjZF) albums (159/394)...
# No existing album data found. Starting fresh.
# Fetched 20 albums (offset: 0).
# Fetched 5 albums (offset: 20).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 25 new albums.
# Feching boys24 (717WLyxCBUBA03fLeWU2po) albums (160/394)...
# No existing album data found. Starting fresh.
# Fetched 1 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 1 new albums.
# Feching Cocosori (4gzfAZ14j11vXC4v01WU14) albums (161/394)...
# No existing album data found. Starting fresh.
# Fetched 3 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 3 new albums.
# Feching Double S 301 (4RUHpfInPElWdPRqbsIjSu) albums (162/394)...
# No existing album data found. Starting fresh.
# Fetched 4 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 4 new albums.
# Feching EXO-CBX (3Lz3vEN23Fw0hIelrYEzUD) albums (163/394)...
# No existing album data found. Starting fresh.
# Fetched 11 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 11 new albums.
# Feching gugudan (0h7XZWgoxlY49uSUj7MVRY) albums (164/394)...
# No existing album data found. Starting fresh.
# Fetched 8 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 8 new albums.
# Feching B.I (0UntV1Bw2hk3fbRrm9eMP6) albums (165/394)...
# No existing album data found. Starting fresh.
# Fetched 19 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 19 new albums.
# Feching IZ*ONE (5r1tUTxVSgvBHnoDuDODPH) albums (166/394)...
# No existing album data found. Starting fresh.
# Fetched 16 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 16 new albums.
# Feching IMFACT (3ejYNz33SNAa1Qxo9g0qCG) albums (167/394)...
# No existing album data found. Starting fresh.
# Fetched 16 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 16 new albums.
# Feching KNK (5zx2slDKDXNn1e6779RzPd) albums (168/394)...
# No existing album data found. Starting fresh.
# Fetched 11 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 11 new albums.
# Feching Darrel Mascarenhas (11jMI9dmkoeyybCWOPLgxA) albums (169/394)...
# No existing album data found. Starting fresh.
# Fetched 2 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 2 new albums.
# Feching MOBB (6r0hPI0NVDMIwJimnNps8c) albums (170/394)...
# No existing album data found. Starting fresh.
# Fetched 8 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 8 new albums.
# Feching MOMOLAND (5RR0MLwcjc87wjSw2JYdwx) albums (171/394)...
# No existing album data found. Starting fresh.
# Fetched 18 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 18 new albums.
# Feching NCT DREAM (1gBUSTR3TyDdTVFIaQnc02) albums (172/394)...
# No existing album data found. Starting fresh.
# Fetched 20 albums (offset: 0).
# Fetched 12 albums (offset: 20).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 32 new albums.
# Feching NCT DREAM (1gBUSTR3TyDdTVFIaQnc02) albums (173/394)...
# Loaded existing data with 32 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching NCT DREAM (1gBUSTR3TyDdTVFIaQnc02) albums (174/394)...
# Loaded existing data with 32 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching NCT DREAM (1gBUSTR3TyDdTVFIaQnc02) albums (175/394)...
# Loaded existing data with 32 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching PENTAGON (1wKpMkucynaTfG8lyPprYV) albums (176/394)...
# No existing album data found. Starting fresh.
# Fetched 20 albums (offset: 0).
# Fetched 19 albums (offset: 20).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 39 new albums.
# Feching SF9 (7LOmc7gyMVMOWF8qwEdn2X) albums (177/394)...
# No existing album data found. Starting fresh.
# Fetched 20 albums (offset: 0).
# Fetched 20 albums (offset: 20).
# Fetched 11 albums (offset: 40).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 51 new albums.
# Feching Unnies (1yiDnFMFWXLovGSw3tcFVg) albums (178/394)...
# No existing album data found. Starting fresh.
# Fetched 1 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 1 new albums.
# Feching VICTON (0ziR2zN0NFcB4x1G3P8cW3) albums (179/394)...
# No existing album data found. Starting fresh.
# Fetched 17 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 17 new albums.
# Feching VROMANCE (5YPW3OmiqnqnQaFjloAvA7) albums (180/394)...
# No existing album data found. Starting fresh.
# Fetched 20 albums (offset: 0).
# Fetched 6 albums (offset: 20).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 26 new albums.
# Feching WJSN (6hhqsQZhtp9hfaZhSd0VSD) albums (181/394)...
# No existing album data found. Starting fresh.
# Fetched 15 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 15 new albums.
# Feching 14U (1vvqMncL3yIIFpbX2oCDZl) albums (182/394)...
# No existing album data found. Starting fresh.
# Fetched 1 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 1 new albums.
# Feching A.C.E (25KT93FeotUTHC1dbLasxi) albums (183/394)...
# No existing album data found. Starting fresh.
# Fetched 20 albums (offset: 0).
# Fetched 13 albums (offset: 20).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 33 new albums.
# Feching BUSTERS (0BIHC8He3YfrhXeECyXSI4) albums (184/394)...
# No existing album data found. Starting fresh.
# Fetched 11 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 11 new albums.
# Feching Dreamcatcher (5V1qsQHdXNm4ZEZHWvFnqQ) albums (185/394)...
# No existing album data found. Starting fresh.
# Fetched 20 albums (offset: 0).
# Fetched 9 albums (offset: 20).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 29 new albums.
# Feching FAVORITE (3o0wQ9s18mlYobc9ZqOs8i) albums (186/394)...
# No existing album data found. Starting fresh.
# Fetched 6 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 6 new albums.
# Feching Golden Child (5zShiwTHlygdfsXj6eavTu) albums (187/394)...
# No existing album data found. Starting fresh.
# Fetched 20 albums (offset: 0).
# Fetched 3 albums (offset: 20).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 23 new albums.
# Feching GreatGuys (5rl5eIP9MogVsjbIVUKK1y) albums (188/394)...
# No existing album data found. Starting fresh.
# Fetched 12 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 12 new albums.
# Feching Hashtag (1SABBqkbfguBXhZQJK5t3e) albums (189/394)...
# No existing album data found. Starting fresh.
# Fetched 4 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 4 new albums.
# Feching HIGHLIGHT (3T0fMfxYBU3q9oAUAdPIsr) albums (190/394)...
# No existing album data found. Starting fresh.
# Fetched 11 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 11 new albums.
# Feching IN2IT (43GYq8c6nVEgaEyg0qtzJd) albums (191/394)...
# No existing album data found. Starting fresh.
# Fetched 11 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 11 new albums.
# Feching IZ*ONE (5r1tUTxVSgvBHnoDuDODPH) albums (192/394)...
# Loaded existing data with 16 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching JBJ (6VJXRJvRRyLv99RZbXJ8RO) albums (193/394)...
# No existing album data found. Starting fresh.
# Fetched 3 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 3 new albums.
# Feching KARD (2JhAlkmukNvarUpGhTFXUQ) albums (194/394)...
# No existing album data found. Starting fresh.
# Fetched 18 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 18 new albums.
# Feching M.O.N.T (205HvlOEb4EZFrBHXv8kLZ) albums (195/394)...
# No existing album data found. Starting fresh.
# Fetched 15 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 15 new albums.
# Feching MVP (2pnxwqYZoUsn4kj3SkJc2C) albums (196/394)...
# No existing album data found. Starting fresh.
# Fetched 6 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 6 new albums.
# Feching MXM (2BXth1dnMzlCfJP9EiCLnv) albums (197/394)...
# No existing album data found. Starting fresh.
# Fetched 7 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 7 new albums.
# Feching MYTEEN (0Jy5VMwm7X25fOaYh0PyXK) albums (198/394)...
# No existing album data found. Starting fresh.
# Fetched 3 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 3 new albums.
# Feching ONF (0eEhOgZ2x6kv8kLz77WO7b) albums (199/394)...
# No existing album data found. Starting fresh.
# Fetched 20 albums (offset: 0).
# Fetched 3 albums (offset: 20).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 23 new albums.
# Feching Light & Salt (0jhgI3xU8n2o1W6EOw9dIf) albums (200/394)...
# Loaded existing data with 15 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching PRISTIN (6VAphrHp0Oc88qg9BDaH9D) albums (201/394)...
# No existing album data found. Starting fresh.
# Fetched 3 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 3 new albums.
# Feching RAINZ (46JpdBeitfoEleoCabDawH) albums (202/394)...
# No existing album data found. Starting fresh.
# Fetched 5 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 5 new albums.
# Feching Seo In Guk (433F0GjVZRnsjP8ztGEso1) albums (203/394)...
# No existing album data found. Starting fresh.
# Fetched 20 albums (offset: 0).
# Fetched 11 albums (offset: 20).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 31 new albums.
# Feching Seven O'Clock (4NeKLW82adFCE8Y6r50X1E) albums (204/394)...
# No existing album data found. Starting fresh.
# Fetched 8 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 8 new albums.
# Feching THE BOYZ (0CmvFWTX9zmMNCUi6fHtAx) albums (205/394)...
# No existing album data found. Starting fresh.
# Fetched 20 albums (offset: 0).
# Fetched 20 albums (offset: 20).
# Fetched 9 albums (offset: 40).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 49 new albums.
# Feching The Rose (5na1LmEmK2VzNLje9snJYW) albums (206/394)...
# No existing album data found. Starting fresh.
# Fetched 15 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 15 new albums.
# Feching TRCNG (07Fxramv7R9p4IHJI7Oeqe) albums (207/394)...
# No existing album data found. Starting fresh.
# Fetched 7 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 7 new albums.
# Feching Triple H (1klFdLh3pak3eOtJP0styY) albums (208/394)...
# No existing album data found. Starting fresh.
# Fetched 2 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 2 new albums.
# Feching TST (0zP3SdsxdXMepTTc22nTig) albums (209/394)...
# No existing album data found. Starting fresh.
# Fetched 4 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 4 new albums.
# Feching Varsity (3T49KbzLgtqWEUhrP8XUJZ) albums (210/394)...
# No existing album data found. Starting fresh.
# Fetched 9 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 9 new albums.
# Feching Wanna One (2CvaqAMMsX576VBehaJ0Wx) albums (211/394)...
# No existing album data found. Starting fresh.
# Fetched 6 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 6 new albums.
# Feching Weki Meki (5LWkv2hDbDwZL3zNwZYNPx) albums (212/394)...
# No existing album data found. Starting fresh.
# Fetched 16 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 16 new albums.
# Feching ATEEZ (68KmkJeZGfwe1OUaivBa2L) albums (213/394)...
# No existing album data found. Starting fresh.
# Fetched 20 albums (offset: 0).
# Fetched 18 albums (offset: 20).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 38 new albums.
# Feching D-CRUNCH (1CNEzaJTiE6s43DHohcujW) albums (214/394)...
# No existing album data found. Starting fresh.
# Fetched 3 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 3 new albums.
# Feching fromis_9 (24nUVBIlCGi4twz4nYxJum) albums (215/394)...
# Loaded existing data with 17 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching (G)I-DLE (2AfmfGFbe0A0WsTYm0SDTx) albums (216/394)...
# No existing album data found. Starting fresh.
# Fetched 20 albums (offset: 0).
# Fetched 16 albums (offset: 20).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 36 new albums.
# Feching GIRLKIND (2TqCaaZ0Yh9MtRVYnoZg8K) albums (217/394)...
# No existing album data found. Starting fresh.
# Fetched 5 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 5 new albums.
# Feching gugudan SEMINA (794b07X4OdSxB97S6X3NaP) albums (218/394)...
# No existing album data found. Starting fresh.
# Fetched 1 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 1 new albums.
# Feching GWSN (5fI4xffqGRGQvICSlJreMF) albums (219/394)...
# No existing album data found. Starting fresh.
# Fetched 6 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 6 new albums.
# Feching Honey Popcorn (1oiPRh43n4MqwL9g9U8IdH) albums (220/394)...
# No existing album data found. Starting fresh.
# Fetched 3 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 3 new albums.
# Feching IZ*ONE (5r1tUTxVSgvBHnoDuDODPH) albums (221/394)...
# Loaded existing data with 16 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching JBJ95 (7G6wtLzZON7qJQ2Cw2kxVp) albums (222/394)...
# No existing album data found. Starting fresh.
# Fetched 5 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 5 new albums.
# Feching K/DA (4gOc8TsQed9eqnqJct2c5v) albums (223/394)...
# No existing album data found. Starting fresh.
# Fetched 4 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 4 new albums.
# Feching LOONA (52zMTJCKluDlFwMQWmccY7) albums (224/394)...
# No existing album data found. Starting fresh.
# Fetched 20 albums (offset: 0).
# Fetched 6 albums (offset: 20).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 26 new albums.
# Feching NATURE (5WUom9mTTEewPdUmI4qnQi) albums (225/394)...
# No existing album data found. Starting fresh.
# Fetched 14 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 14 new albums.
# Feching NeonPunch (1j2VjoyNduKvjsQqiQ6Z5d) albums (226/394)...
# No existing album data found. Starting fresh.
# Fetched 2 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 2 new albums.
# Feching NOIR (5TxoDjQBAZwKnuycBAmHZ3) albums (227/394)...
# No existing album data found. Starting fresh.
# ...
# No next page available. Stopping fetch.
# Finished fetching albums. Added 29 new albums.
# Feching MAMAMOO (0XATRDCYuuGhk0oE7C0o5G) albums (338/394)...
# Loaded existing data with 57 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching MIMIIROSE (3699Hh55qWXd0kWWMWRR2o) albums (339/394)...
# No existing album data found. Starting fresh.
# Fetched 3 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 3 new albums.
# Feching NewJeans (6HvZYsbFfjnjFrWF950C9d) albums (340/394)...
# No existing album data found. Starting fresh.
# Fetched 14 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 14 new albums.
# Feching NMIXX (28ot3wh4oNmoFOdVajibBl) albums (341/394)...
# No existing album data found. Starting fresh.
# Fetched 15 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 15 new albums.
# Feching TAN (34Ecdzh8yGKt2YvPG37PKu) albums (342/394)...
# No existing album data found. Starting fresh.
# Fetched 9 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 9 new albums.
# Feching TEMPEST (1iyFL3CRuKW7PXgPH4VxSP) albums (343/394)...
# No existing album data found. Starting fresh.
# Fetched 12 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 12 new albums.
# Feching THE NEW SIX (0DRiXmEOc6dJ6Rug3xi4HZ) albums (344/394)...
# No existing album data found. Starting fresh.
# Fetched 11 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 11 new albums.
# Feching TRENDZ (6Bmr9e9x44iib7equMj5Qj) albums (345/394)...
# No existing album data found. Starting fresh.
# Fetched 10 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 10 new albums.
# Feching VIVIZ (7Lq3yAtwi0Z7zpxEwbQQNZ) albums (346/394)...
# No existing album data found. Starting fresh.
# Fetched 10 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 10 new albums.
# Feching WSG WANNABE(4FIRE) (5pBMUwsALQyFKrbV2nAaKD) albums (347/394)...
# No existing album data found. Starting fresh.
# Fetched 1 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 1 new albums.
# Feching YOUNITE (4l4eMvpA4K7X02j08cbkNV) albums (348/394)...
# No existing album data found. Starting fresh.
# Fetched 7 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 7 new albums.
# Feching 8TURN (7tCg9aiVKZ5Cmhbfb7UoqM) albums (349/394)...
# No existing album data found. Starting fresh.
# Fetched 7 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 7 new albums.
# Feching 82MAJOR (1wDstpO8XQNU6GV0S92663) albums (350/394)...
# No existing album data found. Starting fresh.
# Fetched 4 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 4 new albums.
# Feching AMPERS&ONE (4T0Chh3DGxJrEs3gM0biqg) albums (351/394)...
# No existing album data found. Starting fresh.
# Fetched 3 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 3 new albums.
# Feching BABYMONSTER (1SIocsqdEefUTE6XKGUiVS) albums (352/394)...
# No existing album data found. Starting fresh.
# Fetched 6 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 6 new albums.
# Feching BOYNEXTDOOR (4hnHLgMSOiqERWBL4jINP1) albums (353/394)...
# No existing album data found. Starting fresh.
# Fetched 9 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 9 new albums.
# Feching BXB (0h6uaOMoZvxw7P0wefWvHo) albums (354/394)...
# No existing album data found. Starting fresh.
# Fetched 7 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 7 new albums.
# Feching EL7Z UP (27xea8r2bsY7UlsbaRiwMQ) albums (355/394)...
# No existing album data found. Starting fresh.
# Fetched 1 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 1 new albums.
# Feching EVNNE (6SYJFHPxXkr4SZJR8aLEml) albums (356/394)...
# No existing album data found. Starting fresh.
# Fetched 7 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 7 new albums.
# Feching FANTASY BOYS (4IAcb0MN1CCHpwUaq5iEUU) albums (357/394)...
# No existing album data found. Starting fresh.
# Fetched 8 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 8 new albums.
# Feching HORI7ON (7xuXBG13gHSpdAoXNWQ8Se) albums (358/394)...
# No existing album data found. Starting fresh.
# Fetched 6 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 6 new albums.
# Feching KISS OF LIFE (4TEK9tIkcoxib4GxT3O4ky) albums (359/394)...
# Loaded existing data with 9 albums.
# No new albums detected. Skipping fetch.
# Finished fetching albums. Added 0 new albums.
# Feching Loossemble (1kbVoxpFh1eDOXumLmVdKY) albums (360/394)...
# No existing album data found. Starting fresh.
# Fetched 3 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 3 new albums.
# Feching LUN8 (5LkLwB6VSZLQiFkJa9SPOn) albums (361/394)...
# No existing album data found. Starting fresh.
# Fetched 8 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 8 new albums.
# Feching MAVE: (2ec7y2L98sHDYFylr7KqEx) albums (362/394)...
# No existing album data found. Starting fresh.
# Fetched 2 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 2 new albums.
# Feching n.SSign (3IHvi45S5SITyNES9VzSjI) albums (363/394)...
# No existing album data found. Starting fresh.
# Fetched 11 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 11 new albums.
# Feching NCT DOJAEJUNG (0W0w607z3JEA1vXLz9FVGw) albums (364/394)...
# No existing album data found. Starting fresh.
# Fetched 2 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 2 new albums.
# Feching ONE PACT (6ypgjfzuOVkVw9FEyh2UD5) albums (365/394)...
# No existing album data found. Starting fresh.
# Fetched 5 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 5 new albums.
# Feching PLAVE (0k2zyzGq6HX383VlMBOvRG) albums (366/394)...
# No existing album data found. Starting fresh.
# Fetched 8 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 8 new albums.
# Feching POW (3aycZMYDTnN0trM2XnTI4Y) albums (367/394)...
# No existing album data found. Starting fresh.
# Fetched 5 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 5 new albums.
# Feching PRIMROSE (1nE2Iu4qK1fzslPJcLGq66) albums (368/394)...
# No existing album data found. Starting fresh.
# Fetched 4 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 4 new albums.
# Feching RIIZE (2jOm3cYujQx6o1dxuiuqaX) albums (369/394)...
# No existing album data found. Starting fresh.
# Fetched 18 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 18 new albums.
# Feching SHOWNU X HYUNGWON (MONSTA X) (3AFqxSVdKDJD9qPx3K8tKg) albums (370/394)...
# No existing album data found. Starting fresh.
# Fetched 2 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 2 new albums.
# Feching The Wind (3q4h0WRGyR0Qcx88vwyzkd) albums (371/394)...
# No existing album data found. Starting fresh.
# Fetched 6 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 6 new albums.
# Feching TIOT (2hoCMH0KWwpjFJEGh0ECe7) albums (372/394)...
# No existing album data found. Starting fresh.
# Fetched 5 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 5 new albums.
# Feching tripleS (5Z71xE9prhpHrqL5thVMyK) albums (373/394)...
# No existing album data found. Starting fresh.
# Fetched 17 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 17 new albums.
# Feching xikers (6QHP8St0MzfNDqjKpwtMht) albums (374/394)...
# No existing album data found. Starting fresh.
# Fetched 7 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 7 new albums.
# Feching XODIAC (1Yhs3H3tkZhk4mSQgzECWb) albums (375/394)...
# No existing album data found. Starting fresh.
# Fetched 11 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 11 new albums.
# Feching YOUNG POSSE (5bxwvIM9PX0CkpS6f1L2Ff) albums (376/394)...
# No existing album data found. Starting fresh.
# Fetched 6 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 6 new albums.
# Feching ZEROBASEONE (7cjg7EkeZy3OI5o9Qthc6n) albums (377/394)...
# No existing album data found. Starting fresh.
# Fetched 11 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 11 new albums.
# Feching ARTMS (213zHiFZwtDVEqyxeCbk07) albums (378/394)...
# No existing album data found. Starting fresh.
# Fetched 2 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 2 new albums.
# Feching B.D.U (1SRmmtrnAo0UK0NUROJRjz) albums (379/394)...
# No existing album data found. Starting fresh.
# Fetched 1 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 1 new albums.
# Feching BADVILLAIN (2Y7fY3aflbCTxp6h5hw0CV) albums (380/394)...
# No existing album data found. Starting fresh.
# Fetched 3 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 3 new albums.
# Feching Big Ocean (0ly1nCJ50by9Vc0UxPHvwY) albums (381/394)...
# No existing album data found. Starting fresh.
# Fetched 4 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 4 new albums.
# Feching Candy Shop (47bUCJh3LXBeQtrTnWEwXn) albums (382/394)...
# No existing album data found. Starting fresh.
# Fetched 2 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 2 new albums.
# Feching DXMON (3696Y4dRCxairFC7sQAuI4) albums (383/394)...
# No existing album data found. Starting fresh.
# Fetched 4 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 4 new albums.
# Feching Geenius (1E9Grth4BtkGuX16ppAVyb) albums (384/394)...
# No existing album data found. Starting fresh.
# Fetched 1 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 1 new albums.
# Feching ILLIT (36cgvBn0aadzOijnjjwqMN) albums (385/394)...
# No existing album data found. Starting fresh.
# Fetched 6 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 6 new albums.
# Feching MADEIN (5Sso2rRE8bs9Ff6bkfqUKe) albums (386/394)...
# No existing album data found. Starting fresh.
# Fetched 2 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 2 new albums.
# Feching MEOVV (08hHTBHlv0WRXWlyrsb6Kv) albums (387/394)...
# No existing album data found. Starting fresh.
# Fetched 2 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 2 new albums.
# Feching NOMAD (3hscj9beAfMyBhBxJsHisK) albums (388/394)...
# No existing album data found. Starting fresh.
# Fetched 2 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 2 new albums.
# Feching NOWADAYS (1iZwr6w3TWPNezX8yCtRBg) albums (389/394)...
# No existing album data found. Starting fresh.
# Fetched 4 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 4 new albums.
# Feching RESCENE (5deOsjuFTKrNMJW3rKuL8S) albums (390/394)...
# No existing album data found. Starting fresh.
# Fetched 6 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 6 new albums.
# Feching TWS (4GgBKgxhc649frZDHcXIEz) albums (391/394)...
# No existing album data found. Starting fresh.
# Fetched 6 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 6 new albums.
# Feching UNIS (48xyu8QHo1IhsQZGlgNGYZ) albums (392/394)...
# No existing album data found. Starting fresh.
# Fetched 2 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 2 new albums.
# Feching WAKER (1JHWiZqATDzLpkKLOC88pW) albums (393/394)...
# No existing album data found. Starting fresh.
# Fetched 3 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 3 new albums.
# Feching WATERFIRE (3WiQKZfcWhqHvCZuU4EPQ6) albums (394/394)...
# No existing album data found. Starting fresh.
# Fetched 1 albums (offset: 0).
# No next page available. Stopping fetch.
# Finished fetching albums. Added 1 new albums.
#                                                   url                      id  \
# 0   https://open.spotify.com/album/4LNAKF3T84CEVfJ...  4LNAKF3T84CEVfJuzgra0E
# 1   https://open.spotify.com/album/1INc7cTUIzcZUzh...  1INc7cTUIzcZUzhlB1N7AI
# 2   https://open.spotify.com/album/3yELvJ2jFxIvmrf...  3yELvJ2jFxIvmrfn8Pgb3d
# 3   https://open.spotify.com/album/0jXyB4zABzmie79...  0jXyB4zABzmie79OTZJgB0
# 0   https://open.spotify.com/album/2rhq834A24z7ucY...  2rhq834A24z7ucY39moYdb
# ..                                                ...                     ...
# 1   https://open.spotify.com/album/3pix2U5QbFUSwOe...  3pix2U5QbFUSwOeF1M9Eim
# 0   https://open.spotify.com/album/1Au58twsgHlicnh...  1Au58twsgHlicnh8IfOJ1T
# 1   https://open.spotify.com/album/4M2nKDFzIDHO7cS...  4M2nKDFzIDHO7cScymLji5
# 2   https://open.spotify.com/album/66dIUNZgjWgAVNu...  66dIUNZgjWgAVNuGh99Zai
# 0   https://open.spotify.com/album/1gGZ22aCiYXKl8m...  1gGZ22aCiYXKl8mgEJdDAk
#
#                             name album_type  total_tracks  \
# 0                           쫄깃쫄깃      album             9
# 1                   COLOR ME RAD     single             4
# 2                         머피와 샐리     single             4
# 3      D.Holic Dark With Dignity     single             3
# 0                       GOOD BOY     single             1
# ..                           ...        ...           ...
# 1   The 1st Mini Album 'WE UNIS'     single             5
# 0                     Sweet Tape      album             9
# 1              Mission of School      album            10
# 2                           DASH     single             1
# 0                       POSSIBLE     single             2
#
#                                     available_markets release_date  \
# 0   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...   2015-07-08
# 1   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...   2016-07-07
# 2   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...   2015-11-12
# 3   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...   2014-10-23
# 0   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...   2014-11-21
# ..                                                ...          ...
# 1   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...   2024-03-27
# 0   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...   2024-07-16
# 1   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...   2024-01-08
# 2   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...   2023-12-01
# 0   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...   2024-05-30
#
#    release_date_precision               artist_id
# 0                     day  1V7MmQ36ihG1f3qe46L50n
# 1                     day  1V7MmQ36ihG1f3qe46L50n
# 2                     day  1V7MmQ36ihG1f3qe46L50n
# 3                     day  1V7MmQ36ihG1f3qe46L50n
# 0                     day  3HJVw8aEtFqoc3raJVE8am
# ..                    ...                     ...
# 1                     day  48xyu8QHo1IhsQZGlgNGYZ
# 0                     day  1JHWiZqATDzLpkKLOC88pW
# 1                     day  1JHWiZqATDzLpkKLOC88pW
# 2                     day  1JHWiZqATDzLpkKLOC88pW
# 0                     day  3WiQKZfcWhqHvCZuU4EPQ6
#
# [3303 rows x 9 columns]

# %% [markdown]
# There will be an album with the same name but it will be released in different places. Please see if you want to exclude it based on the requirements.

# %%
import pandas as pd
import os

all_albums_df = pd.DataFrame()
for file_name in os.listdir('./data/albums'):
    file_path = os.path.join('./data/albums', file_name)
    df = pd.read_csv(file_path)
    df['updated_at'] = datetime.now(timezone.utc)
    df.to_csv(file_path, index=False)
    all_albums_df = pd.concat([all_albums_df, df], ignore_index=True)
all_albums_df
# Out:
#                                                     url  \
# 0     https://open.spotify.com/album/0EDyYMjPenoiODb...
# 1     https://open.spotify.com/album/1jPfpf7xs7P8vnJ...
# 2     https://open.spotify.com/album/3l7Z9jGnQkVjZc7...
# 3     https://open.spotify.com/album/4aTSrfvWihHGW7i...
# 4     https://open.spotify.com/album/68knDSn2a6pQgqL...
# ...                                                 ...
# 6233  https://open.spotify.com/album/6iR6OCxdsSYShgs...
# 6234  https://open.spotify.com/album/17J3JX1Bj85RwLW...
# 6235  https://open.spotify.com/album/4gVkK0mL0fOcKvA...
# 6236  https://open.spotify.com/album/4mg68SLOjp5W527...
# 6237  https://open.spotify.com/album/3j38QJAj13iWNDx...
#
#                           id  \
# 0     0EDyYMjPenoiODb5PYipb6
# 1     1jPfpf7xs7P8vnJV5LtK1o
# 2     3l7Z9jGnQkVjZc7oTPq0dy
# 3     4aTSrfvWihHGW7iUr8ryaK
# 4     68knDSn2a6pQgqLpBGXKHS
# ...                      ...
# 6233  6iR6OCxdsSYShgs3e2kYi3
# 6234  17J3JX1Bj85RwLWWWOj0ih
# 6235  4gVkK0mL0fOcKvAR0Vclwl
# 6236  4mg68SLOjp5W527ufbMuN8
# 6237  3j38QJAj13iWNDx8xnCRTZ
#
#                                                    name album_type  \
# 0     Sapta Sagaradaache Ello - Side B (Original Sou...      album
# 1                               Bheema (Original Score)      album
# 2                    Bheema (Original Background Score)      album
# 3     Sapta Sagaralu Dhaati - Side B (Original Motio...      album
# 4     Sapta Sagaradaache Ello- Side B (Original Moti...      album
# ...                                                 ...        ...
# 6233                                          DAYTOUR 2     single
# 6234                                            DAYTOUR     single
# 6235                                        Lovey Dovey     single
# 6236                                            Salamat     single
# 6237                                               DASH     single
#
#       total_tracks                                  available_markets  \
# 0               33  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...
# 1               18  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...
# 2               18  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...
# 3                7  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...
# 4                7  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...
# ...            ...                                                ...
# 6233             4  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...
# 6234             2  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...
# 6235             2  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...
# 6236             2  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...
# 6237             2  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...
#
#      release_date release_date_precision               artist_id  \
# 0      2024-11-19                    day  002yVW3Yn595KWy74buQ1k
# 1      2024-11-08                    day  002yVW3Yn595KWy74buQ1k
# 2      2024-11-08                    day  002yVW3Yn595KWy74buQ1k
# 3      2024-09-30                    day  002yVW3Yn595KWy74buQ1k
# 4      2024-09-30                    day  002yVW3Yn595KWy74buQ1k
# ...           ...                    ...                     ...
# 6233   2024-08-13                    day  7xuXBG13gHSpdAoXNWQ8Se
# 6234   2024-03-02                    day  7xuXBG13gHSpdAoXNWQ8Se
# 6235   2023-05-31                    day  7xuXBG13gHSpdAoXNWQ8Se
# 6236   2023-04-05                    day  7xuXBG13gHSpdAoXNWQ8Se
# 6237   2023-03-22                    day  7xuXBG13gHSpdAoXNWQ8Se
#
#                            updated_at
# 0    2024-12-04 12:32:13.366236+00:00
# 1    2024-12-04 12:32:13.366236+00:00
# 2    2024-12-04 12:32:13.366236+00:00
# 3    2024-12-04 12:32:13.366236+00:00
# 4    2024-12-04 12:32:13.366236+00:00
# ...                               ...
# 6233 2024-12-04 12:32:17.207526+00:00
# 6234 2024-12-04 12:32:17.207526+00:00
# 6235 2024-12-04 12:32:17.207526+00:00
# 6236 2024-12-04 12:32:17.207526+00:00
# 6237 2024-12-04 12:32:17.207526+00:00
#
# [6238 rows x 10 columns]

# %%
all_albums_df.to_csv('./data/spotify_albums_data.csv', index=False, encoding='utf-8')

# %%
def fetch_album_tracks(
    album_id: str,
    sp: spotipy.Spotify,
    executor: ApiExecutor,
    limit: int = 50,
    track_data_path: str = 'album_tracks.csv'
) -> pd.DataFrame:
    """
    Fetch all tracks of a specific album using Spotify API, saving data to a CSV file.
    
    Args:
        album_id (str): Spotify album ID.
        sp (spotipy.Spotify): Spotify client instance.
        executor (ApiExecutor): API executor for rate limiting and retries.
        limit (int): Number of results to fetch per API call (default 50).
        track_data_path (str): Filepath for saving track data (default 'album_tracks.csv').
    
    Returns:
        pd.DataFrame: A DataFrame containing all tracks for the given album.
    """
    offset = 0
    all_tracks = []
    processed_track_ids = set()
    
    # Load existing CSV data to avoid duplicates
    try:
        existing_tracks = pd.read_csv(track_data_path)
        processed_track_ids = set(existing_tracks['id'])
        print(f"Loaded existing data with {len(processed_track_ids)} tracks.")
    except FileNotFoundError:
        print("No existing track data found. Starting fresh.")
    
    while True:
        try:
            # Prepare parameters for the API request
            params = {
                'limit': limit,
                'offset': offset
            }
            
            # Execute API request with rate limiting and retries
            response = executor.execute_request(
                lambda: sp.album_tracks(album_id, **params)
            )
            
            tracks = response.get('items', [])
            if not tracks:
                break  # Exit the loop if no more results
            
            for track in tracks:
                if track['id'] in processed_track_ids:
                    continue  # Skip already processed tracks
                
                # Extract artist IDs
                artist_ids = []
                for artist in track['artists']:
                    artist_id = artist['id']
                    artist_ids.append(artist_id)
                
                # Extract track data
                track_data = {
                    'disc_number': track['disc_number'],
                    'track_number': track['track_number'],
                    'duration_ms': track['duration_ms'],
                    'explicit': track['explicit'],
                    'url': track['external_urls'].get('spotify'),
                    'id': track['id'],
                    'name': track['name'],
                    'is_local': track['is_local'],
                    'artist_ids': artist_ids,
                    'album_id': album_id,
                    'updated_at': datetime.now(timezone.utc)
                }
                all_tracks.append(track_data)
                processed_track_ids.add(track['id'])
                
                # Save track data to CSV immediately
                append_to_csv(track_data_path, track_data)
            
            print(f"Fetched {len(tracks)} tracks (offset: {offset}).")
            offset += limit
        
        except Exception as e:
            print(f"Error fetching tracks for album {album_id} at offset {offset}: {e}")
            break
    
    # Convert all tracks to DataFrame and return
    tracks_df = pd.DataFrame(all_tracks)
    return tracks_df

# %%
all_albums_tracks_df = pd.DataFrame()
for index, row in all_albums_df.reset_index().iterrows():
    album_id = row['id']
    print(f'Fetching {album_id} ({index + 1} / {len(all_albums_df)})...')
    album_tracks_data_path = os.path.join(
        './data/album_tracks',
        f'{album_id}.csv'
    )
    if os.path.isfile(album_tracks_data_path):
        print(f'Album track file is exists, pass...')
        continue
    fetch_album_tracks(album_id, sp=sp, executor=executor, track_data_path=album_tracks_data_path)
# Out:
# Fetching 7EhwJywfGN4vOD0uqBCirC (1 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 10 tracks (offset: 0).
# Fetching 3d25Sxkvc5QLomfDfUJFdl (2 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 14 tracks (offset: 0).
# Fetching 2jc65r5YsDS9OmGnvY9T3w (3 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 11 tracks (offset: 0).
# Fetching 7qy4orsHqdwoLzf7cfIFSf (4 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 10 tracks (offset: 0).
# Fetching 6kl9ejsgIVeQosQz73VCS4 (5 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 8 tracks (offset: 0).
# Fetching 2nv7hhqj0o86CqKhQ3JTRB (6 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 9 tracks (offset: 0).
# Fetching 3WZKixaKhFcQLEVnInPSeE (7 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 11 tracks (offset: 0).
# Fetching 6O4PjajVTcGFApUJfrsVRw (8 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 8 tracks (offset: 0).
# Fetching 4I5P7duaNVlAGoYpbRTFKE (9 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 9 tracks (offset: 0).
# Fetching 6sS5O1hLftk35nixGbwF56 (10 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 11 tracks (offset: 0).
# Fetching 1SRKJ3RR4TbEYeBL6ATvWq (11 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 10 tracks (offset: 0).
# Fetching 7vNUreP8tB5NJssgN6BTWO (12 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 9 tracks (offset: 0).
# Fetching 7cyTBPJPne4c6pJPedwZDO (13 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 8 tracks (offset: 0).
# Fetching 43StLW2LdY30M1GIf7xSh7 (14 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 9 tracks (offset: 0).
# Fetching 3LrXyrMCP9XrWcJNDcR0qe (15 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 10 tracks (offset: 0).
# Fetching 3qTxNT9XYu8uQEWwrD86do (16 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 12 tracks (offset: 0).
# Fetching 1mMTXBce0Mtzdrx9gu2iGX (17 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 8 tracks (offset: 0).
# Fetching 29nvgsw4OoNqCHKFjFqQwM (18 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 12 tracks (offset: 0).
# Fetching 5Tee8bIpgs2CbUXLSCObNz (19 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 14 tracks (offset: 0).
# Fetching 2XjnNHVxfeU6u705Azvq0w (20 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 1hZCKeyean6Q3HAnWeEMRW (21 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 4 tracks (offset: 0).
# Fetching 6aucvhyY7cTT5YR4Jrnnvl (22 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 6h7fXcp9uP4uS7EzL3v3wF (23 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 4R1nAaDiNKZl4gGDAgp1nI (24 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 6bBN2XTsZBRkXXFJ6aUTka (25 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 5c422XCVf22GP8OEu37NXg (26 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 5SqLkOBKLsF3lgQayHapSK (27 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 3Evgu7Ir0tBMKKjUj5b8F1 (28 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 0v8STCjFGzff9BCQ2sw847 (29 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 6yh9llr0FUUKthT612duR3 (30 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 2eDDzHqHsO5xw8d205TmOt (31 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 3 tracks (offset: 0).
# Fetching 36yYDYPTrqkBBdZntFmXQx (32 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 4LjFeMuMiTggKsYE9Pvn8T (33 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 6U2tFJtla30O9mdJOOozba (34 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 5cxGnszEEEUcQFNLBhkObN (35 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 4f38fAPoDWHoEH9GWu99dt (36 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 4 tracks (offset: 0).
# Fetching 1IIG7e4hgvpjzA7zlvhvlR (37 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 6wKJuWzS3TR8nh3iVCIp0z (38 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 19 tracks (offset: 0).
# Fetching 3vVRp93KR6LMXbhdS4mBTy (39 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 12 tracks (offset: 0).
# Fetching 4kcJhDSoN3Vh3iY9O2QoMd (40 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 12 tracks (offset: 0).
# Fetching 6smo0QzDJ15bp5mUIGeDLo (41 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 1cagygE645hY5Od5ZXPPxz (42 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 6lmAA1d9S1QNJEMpdPhJD6 (43 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 4Koszt7gLzM0PF41QzNhh4 (44 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 46ySzIsg7wEGdgplzorAan (45 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 15 tracks (offset: 0).
# Fetching 3x0ZAy0FkmE65qLUjs86tk (46 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 11 tracks (offset: 0).
# Fetching 5Ccl9ffC4RcaviIHvHFXuS (47 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 12 tracks (offset: 0).
# Fetching 1XhlvC8ZkjEu5gsUCtWRfR (48 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 11 tracks (offset: 0).
# Fetching 4mRn1BuzDnKyUhDFnmRURt (49 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 4eguh1dJUXRh0IMiLKRwab (50 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 7 tracks (offset: 0).
# Fetching 4xcIr0rkoIBPmoSPamCorO (51 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 5eN6KiloNKtNCmteFBXgqg (52 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 5uCFinoHAfvh3RM5UuBhZ6 (53 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 3p68B7ZhETVmNbOov8JcF5 (54 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 7qa8B5WKxdG7ITbyduBkN1 (55 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 1HfTA0xDoZ0mswFO3GB3ef (56 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 6yDtQxvq1XRC7Y5qtS03Xx (57 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 7 tracks (offset: 0).
# Fetching 5k34rAvlw3WV7Kh6dAZnxG (58 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 2kFvUydgrSf8hZCRBvFFw9 (59 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 3VanNBIo8m4zg1hGBiEq5Q (60 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 6t9ikyEj7zxGBnFfHnT9rY (61 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 1yh8C77FghUo8kr0CfygXK (62 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 5rxoFZp0cXApsx4l6VM5Is (63 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 5Z1tcu1kDj50l4IvsdLiKF (64 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 5es5aYwtDOoTldJBiXdghV (65 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 6V5HXnZJwWNbQCzjH2KeVP (66 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 0pZA6lNDLvbIj4mgnqVE6G (67 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 65q2Qo6YgoqsXvg1IgDrmQ (68 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 3tHfeB6fKZn3FGCy7HYBt5 (69 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 7D8qvwDFIyDfQcND2eHUGI (70 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 2itIZTzeIXjJn7sqReMvQE (71 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 24 tracks (offset: 0).
# Fetching 4lRCZxpFrnsWWdeT0T0qVn (72 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 14 tracks (offset: 0).
# Fetching 7KoBvvQAzvuP0ef3WFdsSG (73 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 14 tracks (offset: 0).
# Fetching 42FCxz16YLTZ1nw5lVfpaR (74 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 10 tracks (offset: 0).
# Fetching 7JW3T1eSWGXdc3sV1wjtRr (75 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 20 tracks (offset: 0).
# Fetching 2brjDPJVg8mI8IdpdMmv9g (76 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 10 tracks (offset: 0).
# Fetching 2R3KydNLh2RwgD9X7P5Bcp (77 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 19 tracks (offset: 0).
# Fetching 0L3LiUIU196HVWKRJU1AT8 (78 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 21 tracks (offset: 0).
# Fetching 0FPzOi7YqDtrJAqnfq3O4T (79 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 19 tracks (offset: 0).
# Fetching 1KHUX8OEQtSSi3UtM1lP39 (80 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 11 tracks (offset: 0).
# Fetching 2wXZXILiwOyw9fHs2GQXrZ (81 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 15 tracks (offset: 0).
# Fetching 68OCkwyNqE3u5jtvPHTnVX (82 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 13 tracks (offset: 0).
# Fetching 2EogXJZsAKHJvyH3iDBpZb (83 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 22 tracks (offset: 0).
# Fetching 40qmiVHSRqP78RbDJ8Y8n4 (84 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 13 tracks (offset: 0).
# Fetching 0LCeieLEFrPlCem8kqKehd (85 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 12 tracks (offset: 0).
# Fetching 07h13PO2OlSAnrYYPRb133 (86 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 12 tracks (offset: 0).
# Fetching 6VjZu0I92vdfh4dGEP9qCQ (87 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 15 tracks (offset: 0).
# Fetching 7ouOKBMuNwrBddH82YWTmO (88 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 4 tracks (offset: 0).
# Fetching 2tb2AzY9uac3ND3Wf8RQPL (89 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 3 tracks (offset: 0).
# Fetching 1ijtrIo5LrIB0TxJVFXNUL (90 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 6Zl0D9XFhobgDimpSiE6oO (91 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 511cjzFBDWiEpagGyq69Ro (92 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 5ZAg1O1mNNHs1On0Nr8RSH (93 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 6eQSS8h9cf4zhPHha2I4qX (94 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 0bJigZen9yCatAQwftdGsL (95 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 14sqeqbC9Nhc8sgU1SCkGG (96 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 6xJLqtpHiBNK0ufYIIaifG (97 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 7r2Iv4VbmynU7Nb4loXMaY (98 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 4 tracks (offset: 0).
# Fetching 1ZMNazrwSbvJWFetAbNawW (99 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 3 tracks (offset: 0).
# Fetching 6c8CD9p0mCB9R4GqVqABI3 (100 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 5 tracks (offset: 0).
# Fetching 0v4RhmyMWVtCsL18T5s3dl (101 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 01R8nApUyTf5wxd2UWvyGj (102 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 4AGt6380XlkDfOtEOvQZu7 (103 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 7 tracks (offset: 0).
# Fetching 4vOrKQQbPSjYGQRbixrdRi (104 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 13 tracks (offset: 0).
# Fetching 5HJlU2VjYPOd38oAYJ1Zsm (105 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 14 tracks (offset: 0).
# Fetching 1d8wq1eY5iDOcqZ2kza4PK (106 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 17 tracks (offset: 0).
# Fetching 7rFlmSaqKlcXfHJJn5QzdB (107 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 12 tracks (offset: 0).
# Fetching 0dFkBmGAmfBu0rmwkoqBt4 (108 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 60vmoSS3qM37rvPm0BdxsN (109 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 27kavo6TnxYtooalFp34OH (110 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 0wLCobJuw9BcWtoVvbIYXf (111 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 4NgXpcZ6lul6Ax9Wf1DJI1 (112 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 37BzsG0I20mbX2CFipkt3A (113 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 017aEEelOtuBy22ROLHDH4 (114 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 1fNi30H4tevYJlYgMKV2jn (115 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 7vkiYa6FvthMb7Gr80widI (116 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 6hx8eAhZ7QCExsJT4xbOCl (117 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 59C22yjADvjTFLdsfGh1oq (118 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 3miseS4D2MdMgWdi66W9Tv (119 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 0eJ4h47ujRGfEeURzCEZiA (120 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 10zyG0ZN07o9QFfjif7ToP (121 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 3phzWEdBSXbfnsSiRb9ZBS (122 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 4RfLKMKI3rnk5Qxgl6F7YW (123 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 3pMTUgwGDLIdbBEKENCFti (124 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 2YMKq3BEofn0orDoyWr10B (125 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 6azX2bMmuIPkeSLQ9yqeuO (126 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 5u7yBJRS4RZK8WzAnswxg7 (127 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 5ron6TxREIKtGLYTCzDssf (128 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 4cFwElMUid93fPTiRFrMd5 (129 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 0J4wqPSnif0xTlrXrAHDOq (130 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 4LGqCVppg8PsAPqfVjDPsx (131 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 5qjy7sPDiBPNf8hEjMNhEj (132 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 1MUyyE12R9UI3ySu6QPBvz (133 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 5bTl5nbWOySYjX4eKjhvTQ (134 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 2oIxXrHgAZUXZtAaMVcu4r (135 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 1xbVquhWtwl9LIhESXAs28 (136 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 7f7RUXaKR4Z5SYpKCTBzEE (137 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 54P1MSGvQt3Hq1UpsijMgA (138 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 1kTCMrFYi3Y0ruXFCYxOAs (139 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 7Ko2vZAisIK6lWcWrgqBw2 (140 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 5LRBL6iBGlg9mwoXlIlusk (141 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 5gfOqZZOcOJ3PcviA3avji (142 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 5A0tkH84MrCYtCVat8MVCZ (143 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 2Qtp5lC6y3XJTFYUNiAON8 (144 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 4ZtWyXeNobARrQNl3hMA46 (145 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 4 tracks (offset: 0).
# Fetching 0Lkv6Wz4Ix3z9oLg0OcBP7 (146 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 5HOLb1Hdf9asv3tWWiUkva (147 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 1b16TmCgcdPKrqnRvr3kzM (148 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 2ZINBBhWxRLXLwXQSY2DsV (149 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 1E2E055QgHNMeOAnVH5qTZ (150 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 32hecqycCp2ygKgWu4Mcms (151 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 117DMLKawq4FSGciupbnsE (152 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 0ePSI0rTlYpfy4xZ8ngiGw (153 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 0pZqnpmcq3KvyDrguDdfbX (154 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 7z1mrQMFWK91y9H2TE4v8t (155 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 3E8XbM9gn0N2V5bkRaDDHA (156 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 77yVmZ8Cmi59GKt7Wq1Ihn (157 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 7wJtLZcPkZ2KMHVCKk0TFr (158 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 65FZHpiVL7R9XfDLjWJ620 (159 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 2p9kNAjssXwa1uq3SP43jf (160 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 7Bh348BWRGbDA1uNvwlp3f (161 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 3HTalWqVUBJ7gdZovCBIbE (162 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 00RsIfvlMveKYaAhaF27N9 (163 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 2kghhATaj2NIXwoHAf93sw (164 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 3m9qyFH3Mhzm7vpZo02Pyo (165 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 3PwbMb4Ba59liHnmjUb20v (166 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 61YWPDqPw7XMzzUe23UdAG (167 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 1Qxb0cGYsIJVg46UEM16vU (168 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 0vre92JB7wzgioNG9Rea1R (169 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 17 tracks (offset: 0).
# Fetching 7C7ZxNuDhbVd8ykWQdrteJ (170 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 7 tracks (offset: 0).
# Fetching 7zXb9k3ezLLT5BAgHeSleh (171 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 19 tracks (offset: 0).
# Fetching 7AujHzdkOYaeBVlhA7Z23j (172 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 15 tracks (offset: 0).
# Fetching 51NQxu89Z3tkaiLN4GX3lL (173 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 19 tracks (offset: 0).
# Fetching 7zM9ILBsO6580uSLZzV8hC (174 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 17 tracks (offset: 0).
# Fetching 2ol4JeQEAQQFbL8fdP2qUs (175 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 9 tracks (offset: 0).
# Fetching 2tvQHzh1mm7bc3XjyYv8MB (176 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 1npcxvBKVQ5xy3LVdu3Nn9 (177 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 8 tracks (offset: 0).
# Fetching 2XMMAY5KzCIRYdpuK3HK6P (178 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 4 tracks (offset: 0).
# Fetching 0QQ8XYxk8sYaLoLbcZljHg (179 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 0hO2GPaBOsrqIp3e9WYVPr (180 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 0brBmp8gzDqRV7hvYmUAgQ (181 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 3zdBqTEyQcov5ZvKoeRRJQ (182 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 4 tracks (offset: 0).
# Fetching 1II4czjwQUNK9VaP6lcjLv (183 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 3 tracks (offset: 0).
# Fetching 54Qjx88avJ5rvTPtsdhNqs (184 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 4h4LKGYNKz2gXaohJZKXY0 (185 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 15 tracks (offset: 0).
# Fetching 3lBX7AtzE4JoZaAIBLptRx (186 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 32 tracks (offset: 0).
# Fetching 4gkwKdH3BXkdGbbaFQpnz1 (187 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 12 tracks (offset: 0).
# Fetching 6HSiOQVxo7HrYf05PcLC0S (188 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 17 tracks (offset: 0).
# Fetching 4IjRikscB01fLT0BtKT5g5 (189 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 16 tracks (offset: 0).
# Fetching 3CBcuIFKPBBTHy7wLfGudH (190 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 18 tracks (offset: 0).
# Fetching 2oRX6o3vzi8w3EQQla48LW (191 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 4ArOG7wTFTDM7Sqc2XPB0Z (192 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 4dQ7f9UXqzUzFqYMDEC0AC (193 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 20 tracks (offset: 0).
# Fetching 4I6px53lYqErgJcsJkUNlu (194 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 10 tracks (offset: 0).
# Fetching 2YdaEGkcJ6rdBQqDE7pBcZ (195 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 15 tracks (offset: 0).
# Fetching 0pHTB9s8eflsnSSIhrCBEY (196 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 7 tracks (offset: 0).
# Fetching 3RvQNsCUhHOzamL5jQ4POF (197 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 13 tracks (offset: 0).
# Fetching 0ipyHYAE0cMf4aDJNIDIU1 (198 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 11 tracks (offset: 0).
# Fetching 7uJVnFeX20nqjEhI1drwu6 (199 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 10 tracks (offset: 0).
# Fetching 70Y5TFHOKuJF8knX5sUdIE (200 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 14 tracks (offset: 0).
# Fetching 0EsY5ILLEfwUaQjON4RNMq (201 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 31 tracks (offset: 0).
# Fetching 3syxKIJgi0KrdmLAIu86YG (202 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 14 tracks (offset: 0).
# Fetching 2vYBL8e2ils5F0pTLumTjV (203 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 15 tracks (offset: 0).
# Fetching 0525slOQ0sqfjRugRUJUlq (204 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 12 tracks (offset: 0).
# Fetching 2wSlc8JkMQeEzxGQXcVfY3 (205 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 12 tracks (offset: 0).
# Fetching 2cMjjgRPQ0pCcvA7cP3S0L (206 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 13 tracks (offset: 0).
# Fetching 5IW0qKf43owlKTiI5NsKBm (207 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 11 tracks (offset: 0).
# Fetching 1y5wSe8HJaeVg14dOUiKaQ (208 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 15 tracks (offset: 0).
# Fetching 0LF9WwwqLMOEUS2He9I326 (209 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 14 tracks (offset: 0).
# Fetching 3lMEN4CHeWygWVQlSVL5on (210 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 11 tracks (offset: 0).
# Fetching 3N1m3u4vqdpwj4V5oh7C13 (211 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 34 tracks (offset: 0).
# Fetching 6x15RBkd0Dkt4xqKAN1iKv (212 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 19 tracks (offset: 0).
# Fetching 51Wmrzs9O87YlKp2vqDwln (213 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 13 tracks (offset: 0).
# Fetching 3UjBMKbTeyWpa4y7Ne08En (214 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 36 tracks (offset: 0).
# Fetching 7vEPUnwM1HMlm6aEWr7z2h (215 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 34 tracks (offset: 0).
# Fetching 2adPdNYrrTt2tIkthQN5ee (216 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 11 tracks (offset: 0).
# Fetching 5AH1QpZf94kaiWuLXbmTIR (217 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 12 tracks (offset: 0).
# Fetching 01rkIVf8oC86E87jWGuS15 (218 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 8 tracks (offset: 0).
# Fetching 1013imXHa490acqEZkQpeX (219 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 14 tracks (offset: 0).
# Fetching 52AgYWP0UZeNRxdwUrl7rz (220 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 1LfN5LD2GYXbLMUPNsP6Vm (221 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 1VeMx6yfm2e6nuemMfUuNF (222 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 4 tracks (offset: 0).
# Fetching 7c0C835UWVrAkQYjnBrwcT (223 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 4apOFp29EkxRXbDlKNxb9S (224 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 4 tracks (offset: 0).
# Fetching 2Fu6s7oGgT1Ap3I2xZqvGv (225 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 4 tracks (offset: 0).
# Fetching 2UP7NsOKpBRlFUfJSCLsv6 (226 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 0G2cUavLBvDifRqcO1d9qJ (227 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 0wiDsT5Ixi0U1ZjsMV3HpH (228 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 4Zrx5cFDBRXlNSplCFIwC1 (229 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 4 tracks (offset: 0).
# Fetching 1oMAiAhhX2cRL6IgIjKM8c (230 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 4 tracks (offset: 0).
# Fetching 4kox4tQOGLyb4B5aNZ6mr6 (231 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 4 tracks (offset: 0).
# Fetching 5keKjQDpDVgAI0f3nFsm2w (232 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 3 tracks (offset: 0).
# Fetching 6IJ9XPqWX4ub73vs1OB0Xt (233 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 6HzthaCVkTDDMbc9fnzhNy (234 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 4xdt3SxIdXAEwU5MMLuCuP (235 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 6bVjlEM80VG0H30ZTINOSh (236 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 26SEAvtJzRl4Wc1lm8UOWz (237 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 4wOSe34mYXuiF6lyE0NUDu (238 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 5c2q4owNwpzZbkD0gtlGWY (239 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 1JUqWjee5xp6CCVfvjDECw (240 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 4KaoxoeDCLSnvjGvhJZNLC (241 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 5MXTAatPhoFieDzUZDIDoj (242 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 1TWNgJOIm0whNZP0Np3dak (243 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 5AFTg1H2Xc2wXTjz40FXhv (244 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 0Xdww2RH432K0Y0ccT6WVS (245 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 0a4wkWvQithhzP7L9K3VuJ (246 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 4 tracks (offset: 0).
# Fetching 4qIxVpGQdjpO8DhXaHcNHy (247 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 4 tracks (offset: 0).
# Fetching 1VukyPyHadZl6En9cOdMxm (248 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 4 tracks (offset: 0).
# Fetching 75D7tsP1Lv8FIkTDHqgR2H (249 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 0w5txVTeRhc8BfA7dg4noa (250 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 3cSN60IWlvmvzwiRzvjmpf (251 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 5 tracks (offset: 0).
# Fetching 1GJ8NoTelKLdQMyTiftqAo (252 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 27 tracks (offset: 0).
# Fetching 2BTHtE0u22AxaxqsU538BC (253 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 13 tracks (offset: 0).
# Fetching 69rwgUoFeUWO9MldOT5MVn (254 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 204RWZtJ4POzEANEfc0d9m (255 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 4QuioXphvFEWHvkKtJfYgL (256 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 3F3UY7Ci52dYI42D05UJrQ (257 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 3duVRHl0z3p7onbm6aVJba (258 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 56eRb1slRXPn1tNNCCqEJ9 (259 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 56HfP8AGEFwJTcUCbtCiUl (260 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 3gEjYcaXw8VTydeF5UiNuw (261 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 0BOAxVFae0yjgfotU4rkHB (262 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 5cmuV2QDIbDKtFTyUPnZeW (263 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 7iUs8ROM03kJV51aL6L4pQ (264 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 30i3sQtE15OoWrqfEIYsaY (265 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 4hKRV8y5RykSARPahXCc0y (266 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 27ht7C1ABq36tw7Z6wMlkE (267 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 2sgTFZ10mGxm4LUUsFEVKF (268 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 7kFogQ328dyyxoJOpUR2T2 (269 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 0PhHaGe48jujh08IIgQ3pf (270 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 1TRXEVNutsG2bOIIirNWhZ (271 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 7fxPP4syvsTS5nwJvcoaOF (272 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 0w6CX5FXd8vFazo07H67j1 (273 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 1SQ4FGINMVHEz8bldhoyZ6 (274 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 4XbJaMyhkwtvmRSjxVVLj6 (275 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 6c03zDtLCKslGC7KZ9SGFW (276 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 2rhtIHpFyN78QGIMtwE3zC (277 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 4N65IqfFfqtu8YYspeBOGT (278 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 0seIf9LqYov7xHFXfK04z5 (279 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 5 tracks (offset: 0).
# Fetching 4HSU2G2iOU63BPEsfNGIiH (280 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 3xAqrLJep61F17GfRASd1g (281 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 4 tracks (offset: 0).
# Fetching 2qyoiES8BOX1PdRY3eu0zn (282 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 2c9WhlTKVDWzTIVaHKUebH (283 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 10 tracks (offset: 0).
# Fetching 7zETSRIsZuKuk9mOLLFm8Q (284 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 9 tracks (offset: 0).
# Fetching 4ErRENNRVzGqCi1qC33FII (285 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 9 tracks (offset: 0).
# Fetching 3tRtd4pPufUHTVzoiym5DG (286 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 16 tracks (offset: 0).
# Fetching 1bUfyxxpQRoReADfYgkBm4 (287 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 12 tracks (offset: 0).
# Fetching 7GGfsfrAG1qzMkLvpRS6yD (288 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 13 tracks (offset: 0).
# Fetching 3dYxkYqczXopqHnqSXOoP8 (289 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 13 tracks (offset: 0).
# Fetching 4Pa0yl5ddFwSoShkGMJXSu (290 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 7EiYVz1W3OZ1XCP5ukX9cC (291 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 3USSmhkxjaTnWHN7xRsvzO (292 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 6LJH4oLLxYXBjR4ptkDYfU (293 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 68uRuJ1t1qlRSo2GRpSa7N (294 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 7 tracks (offset: 0).
# Fetching 0Niyi5Q7b7XmIbUZ21Ybr1 (295 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 5jlpftPRanecGtXPESkTL2 (296 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 3dcUeThwThBMBE8yq9Jjd2 (297 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 4 tracks (offset: 0).
# Fetching 0uyQDNFg7AdQ25hznC9UD5 (298 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 3ODtnUBsK7y6qH0rqUkmWM (299 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 4 tracks (offset: 0).
# Fetching 0aIheJ3j3UVbeJnqswW27O (300 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 7dRn2R35Oa7dtzh1NN1BOz (301 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 6UejwGjkeE7dobM51RPT3c (302 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 3tXM5SDyfflJHufYaC9Ye7 (303 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 3 tracks (offset: 0).
# Fetching 2GN8ULZGoZSh0MFhSr21HX (304 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 3pEjKt5Gu8v3gQOif9i2MC (305 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 8 tracks (offset: 0).
# Fetching 2XuAoIKGGTVEkmPQIA567M (306 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 56N0qrYzRJQqMbLX2jR9fM (307 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 6YeVDtvHc50yCyspr0djDN (308 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 0xQUMoXawl98xkyzD0PNCG (309 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 2X6uIoSO7nLSM33MwliPo2 (310 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 8 tracks (offset: 0).
# Fetching 3MNCsorakSBIVtsP3Z9JtO (311 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 1EuT9MjVl0pZWe4U4BAH3w (312 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 4wsmm3p8NpnUnIykc5dST3 (313 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 4AcSmPAmoInDzLHOTk0pPX (314 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 8 tracks (offset: 0).
# Fetching 6q0t5xna9kQTqdDh7ur39e (315 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 5vRPRkkabuD90gXPA0dqfN (316 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 0dn6NuF0bc7da9FObqoSWB (317 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 44Nmfbo2Y00rWybaOKok2M (318 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 6bTWwKeRP1GSg5oO5aAfxN (319 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 6pehvwO165NUHnrHxB6ony (320 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 6NCev6GicJ4QXgb8ztOXlR (321 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 7avp7b7LcWZIDZJoYN16jl (322 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 7 tracks (offset: 0).
# Fetching 1UUH6LEMcOIpy3sh3BeA3z (323 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 0Nw1Q47Xu8sjJWQcumU9vK (324 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 7 tracks (offset: 0).
# Fetching 6ByWCmauNGv1jByjLzEBSX (325 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 1RyjnbnhsB9t6TFIsbzpHB (326 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 8 tracks (offset: 0).
# Fetching 7sebA5C1RxggcXCiAvH5Tt (327 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 8 tracks (offset: 0).
# Fetching 6xn4sNk7LNj73gUHc7Qt6z (328 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 4 tracks (offset: 0).
# Fetching 1svSQPZaF55TOVETUHBPmI (329 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 5 tracks (offset: 0).
# Fetching 1XDYplZb2ZMPZTN6qCXBzO (330 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 3 tracks (offset: 0).
# Fetching 1ccWKewD7wsH1T5Mgj4PTe (331 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 1upCkpcvmtKQVzjwPPndMh (332 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 17 tracks (offset: 0).
# Fetching 21CNe92CgEJLneD5NTFeOG (333 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 13 tracks (offset: 0).
# Fetching 3sqAmRZUvZf98nd7R1Qlpn (334 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 11 tracks (offset: 0).
# Fetching 0c9LKPC123b61FftdwBNII (335 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 15 tracks (offset: 0).
# Fetching 67VGH9BtW8KUmAtfIm5a2N (336 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 6k16yhvezz8OZfMFw7gsoC (337 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 45b7ZY0JnkHSXOvIph0a0s (338 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 5 tracks (offset: 0).
# Fetching 59GgMBWtaMXe4vwWLkeVfa (339 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 3 tracks (offset: 0).
# Fetching 2tQzhjCn57QSOnjE2ufegl (340 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 3 tracks (offset: 0).
# Fetching 0oxi4BrOrM7neWUrI5GLtC (341 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 4dx3zqc1Mv5qKkNJdaLNYb (342 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 3XoemveVVhEFXWbWgyzKem (343 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 3vYzEJLKq01ENIrOFzEOAX (344 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 3 tracks (offset: 0).
# Fetching 3WTcwIcYSp96ELb4v7lcuv (345 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 7IzthzQpYRnxjMN99iwPlX (346 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 2HpU5ApLkQsMwLnpsrSo5c (347 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 3 tracks (offset: 0).
# Fetching 6h7Xl8aUEa20EMUsjBIrC4 (348 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 0lcQabxtlZnGeMJqXnKj3g (349 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 69DC3LvoB0z8DUSwMKZSK7 (350 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 7HL1jKi63J596ovjPoEm2c (351 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 4WVAXSLf0mifQOnCaT4P18 (352 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 7MQjSzoWRGj89XhpyZl6yZ (353 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 3OeVNDfu1hBz3NQoviWD1I (354 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 5GvUrplXmoAHl3jW1PV00C (355 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 1gYLn27nnd7wCWt5kvvGlW (356 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 5r0EVa4QA5EHKSzFQLwFeq (357 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 5 tracks (offset: 0).
# Fetching 4EHODOiWI0t2ojsN5Oe8hK (358 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 3qyzxavqOfixEPDfFCEMlH (359 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 10 tracks (offset: 0).
# Fetching 2rKWBsMfhY7yUd6KczLAod (360 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 22 tracks (offset: 0).
# Fetching 32o8mUN1uID4VlBUrsCN2f (361 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 14 tracks (offset: 0).
# Fetching 7jKVdT1syYOuRRWcjo50og (362 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 10 tracks (offset: 0).
# Fetching 5uxH9so2Yrmi6nLClUZJkv (363 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 15 tracks (offset: 0).
# Fetching 1F7DAPXJpLVKfyZFSFsrCw (364 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 10 tracks (offset: 0).
# Fetching 00liLag29Sf9APCrvQn7Hy (365 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 36 tracks (offset: 0).
# Fetching 5Y9nZkvkTcnbyiOfZ2l3rT (366 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 31 tracks (offset: 0).
# Fetching 2YFurqloMyEncsFHOjIbm2 (367 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 14 tracks (offset: 0).
# Fetching 4YdR3Qy3eZXsLGIXaEAw8o (368 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 10 tracks (offset: 0).
# Fetching 7gFooxnJFXgFMbKD8ySZDz (369 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 13 tracks (offset: 0).
# Fetching 53i190Z2uGOLljuS3DCvz2 (370 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 10 tracks (offset: 0).
# Fetching 0zYeZStiw5g3ZSOdVfIRrN (371 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 23 tracks (offset: 0).
# Fetching 7ddh6NqDujM2uyb361VQN3 (372 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 45 tracks (offset: 0).
# Fetching 5qlpNPHBw11axwSZzVKM3C (373 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 14 tracks (offset: 0).
# Fetching 1A8GN5ALgg4TznPJ2LVzmn (374 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 10 tracks (offset: 0).
# Fetching 6tTeFkBVBVazDYDMpAytDD (375 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 37 tracks (offset: 0).
# Fetching 2Si5djz2zl4btKq3rMuE63 (376 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 17 tracks (offset: 0).
# Fetching 0eouyQPmljivHfUuG5nYBa (377 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 13 tracks (offset: 0).
# Fetching 6KGCyNa21pfeox5jXQVi74 (378 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 15 tracks (offset: 0).
# Fetching 7pPLMINIGSzIEczVTCnIxp (379 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 11 tracks (offset: 0).
# Fetching 5LEUXp4BqRNYvg71jmliXx (380 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 39 tracks (offset: 0).
# Fetching 3v5XUoZzxbmJbxs7vWTua3 (381 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 12 tracks (offset: 0).
# Fetching 7iLEumOEyYFsprOdFb2jHT (382 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 36 tracks (offset: 0).
# Fetching 31q68enr8bT14QjoC04BsZ (383 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 14 tracks (offset: 0).
# Fetching 5qP97X9XW3BqpGrqtbcm4C (384 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 11 tracks (offset: 0).
# Fetching 4uVWubQu7a4IjEv6B0n6R0 (385 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 1B3ZMbdmeSFWI2WmXTD0Ny (386 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 5 tracks (offset: 0).
# Fetching 31WEkr0PFjRjRWszhYchtp (387 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 5 tracks (offset: 0).
# ...
# Fetching 5UptJpa7BKnQtDoZlSsC29 (1342 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 3 tracks (offset: 0).
# Fetching 32yLwah52iyVM8brzhtsqT (1343 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 10 tracks (offset: 0).
# Fetching 4osZxBjp9NP5NTuliow4HM (1344 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 2pcBuusnAmUhG0hiK25FJ7 (1345 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 8 tracks (offset: 0).
# Fetching 6J5eNY3zuStyhYXqwZ3431 (1346 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 68BM4keQePES8rx9dzNScv (1347 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 5FdfEIe6R4EQ7caew0KsAv (1348 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 3eOczEhdWiKISTGsQTQgv1 (1349 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 49IdAX27s2YVg9Nll3h22F (1350 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 6wL4AP69zCXoeLapz2heCE (1351 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 8 tracks (offset: 0).
# Fetching 56WFA9DY6elZw9uPt2xGcL (1352 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 1b50QetyAB9rKFkqyR0YtQ (1353 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 6W8TGDGKlol8hov5dpNanU (1354 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 5IWVy3JWoCXlCm4nMuPLML (1355 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 5VeFBwDsdTaWEc85S9hgIt (1356 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 3 tracks (offset: 0).
# Fetching 4Lgxemzl6UcyS54Cw4OnKJ (1357 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 9 tracks (offset: 0).
# Fetching 1BBstIlyiJqzVI1KzbGEQ5 (1358 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 11 tracks (offset: 0).
# Fetching 6eY3DPEilLDTUz99goTwaC (1359 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 8 tracks (offset: 0).
# Fetching 5p7qdLAGInHxGWa8PggJeS (1360 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 7 tracks (offset: 0).
# Fetching 1TtTMVlPNvlpbzL2YnXes3 (1361 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 14 tracks (offset: 0).
# Fetching 7ocKLfx1QN0EBj93uzLzOb (1362 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 12 tracks (offset: 0).
# Fetching 0RPXqJPuiBeXYkjpqDd7YU (1363 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 5 tracks (offset: 0).
# Fetching 4QxOPMGH8Oye9dNxnAOfol (1364 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 3mCKknvSxoGVEv3cE4iqwy (1365 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 1wHKdWLlIXiuJ94Wrzgeun (1366 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 1bM00ZccXBec0tcO7ozcEi (1367 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 1oaHCvGDasGwfGZTdkW5To (1368 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 6JotpS88905tmBAKmjSwAU (1369 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 0DDJRS9fsRZXl539w6F5WW (1370 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 5CDDejh9ESWzsIDnqPY7aM (1371 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 6TcFwzPesuskRFjTQptrl4 (1372 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 3 tracks (offset: 0).
# Fetching 2wDAtUTskew26shSQxd4EL (1373 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 5EB6YZvj8qutF1iKcrgw6j (1374 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 2EO9XTcH2FTqdl99KFOgZD (1375 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 62NUU6QQxhaBCoVxE0wD7B (1376 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 4 tracks (offset: 0).
# Fetching 6NNEIGkJ63mAxSA6fdsjow (1377 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 2yLpZZ6W01CqesccYaxEkL (1378 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 4UYktbMekvR3lyX6uHqHLU (1379 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 4SrpiSolDATBEsz4UvSUGS (1380 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 6BYSBdAoqUgWoipCmIYnP7 (1381 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 5 tracks (offset: 0).
# Fetching 4G7NM3jbPkFegKynGna26n (1382 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 5 tracks (offset: 0).
# Fetching 7xtsbErVzHdz8iZFCmtow8 (1383 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 24 tracks (offset: 0).
# Fetching 3c8URkSWZQC1hrRcL6Pf84 (1384 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 12 tracks (offset: 0).
# Fetching 2IrXOJ7azuX8wO7Zs5TsTj (1385 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 12 tracks (offset: 0).
# Fetching 0vOqi2kac8ZLy4pQaDKKV2 (1386 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 2xllaeCATVxGCV0MVBvnlA (1387 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 2hd6c7LKd4QxKj6Y2tonvl (1388 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 5 tracks (offset: 0).
# Fetching 6bzs1a7zc5cdH0bGxoYglE (1389 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 6nQ20undvjcYJLOrYvHL8T (1390 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 3 tracks (offset: 0).
# Fetching 6p2lS1PUNUMMLRoce5Cg4V (1391 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 66a59KK699I9lb4uVN4JwV (1392 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 3 tracks (offset: 0).
# Fetching 4Kj6IIH5A0yKlCMNVWlwAv (1393 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 3 tracks (offset: 0).
# Fetching 7Ax1kSdzHsojRrtVo1tsAe (1394 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 1ULIHptqbNulrdh0B89WZe (1395 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 3 tracks (offset: 0).
# Fetching 2k49kug0lVoLqocHaKIrF1 (1396 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 5 tracks (offset: 0).
# Fetching 4xmxomzIJuWy4ZRB5uSwjL (1397 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 4 tracks (offset: 0).
# Fetching 0yG2HJFVqLs2EGhFEFSWjb (1398 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 6 tracks (offset: 0).
# Fetching 4F1gwkUtvhcUDQrWxcOmfh (1399 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 4 tracks (offset: 0).
# Fetching 24oBsgU1zEh9U1N9k4WwnN (1400 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 2 tracks (offset: 0).
# Fetching 24DsgIVCxaDzeKN7csl4F2 (1401 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 53uVbadzLXaUZLeFzijCvY (1402 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 3 tracks (offset: 0).
# Fetching 3kkbgtjjMsWmXsEGYexBtr (1403 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 3 tracks (offset: 0).
# Fetching 7tPVswG0kOz169JuZzp0qy (1404 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 9 tracks (offset: 0).
# Fetching 7r4WUsBfxj6tr1cfkGX4sy (1405 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 8 tracks (offset: 0).
# Fetching 7iJDbZs2pDFSe9lDTkFNf5 (1406 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 4jkfVCNyga6roofZDPQoOx (1407 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 4Hflv6CfwsvFdDGcGPnGS4 (1408 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 6mykJZSX2d62iWKExAa42R (1409 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 2aTnz4Bzegqijgz4JnmHxT (1410 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 6I7hH7VjxDH6YMewJkb6O3 (1411 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 1hmWAMWw5tfAQdYS6sYmSN (1412 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 7rN1Bsdky0jJrZ4WXsuLWW (1413 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 6VaA2ab9EhZJgEly8WhTc1 (1414 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 5wU4kHHKADHgyxbPv4zISR (1415 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 35D4HB37k9K28sGaTpo8yS (1416 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 3IXjcVNVlfqLHS7dbwiPi8 (1417 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 5M9qzgDfUSAYWDVEfqSgYs (1418 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 5LyycsecWtkRgDdvElFfmq (1419 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 7AIYkAFaJneFc9lXLc2SEG (1420 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 2knuNP6XLzxIvisnNsJWYD (1421 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 24OgnFicjhbx1nLv10EzsG (1422 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 0ccmhOvuQ6wOvhCjjTLpEx (1423 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 3PnIHcrKtRu49J2rZ5M7o5 (1424 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 50aUXVEfQAlfWXPXcIOJds (1425 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 1pSr0O4pmcy6qOkvybKoHX (1426 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 1sD8pvkP85JoYHYZEOBmgU (1427 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 3hsMiqwJTCM2LMNA2SEaxV (1428 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 7uGDBM7rCFfzOkix8P34eW (1429 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 56UBTwHhtkwfYTDEACEzmO (1430 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 4KLwdHhRrqj4jZRLAhPsJQ (1431 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 4uA1aUBRg0vbj9NonZma2n (1432 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 5F37t0CrAmXt94z050IJCA (1433 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 6jRMRQZLYg7OZjTQORPmWh (1434 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 65CoqM4kbPdTuAxOllCckW (1435 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 6VPyswxOlbDjNbTjKTW7uz (1436 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 20XLKA3RDf57bXI37QxFB2 (1437 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 677luqR7Scfvebkhl8yDeZ (1438 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 2CkD3XAXQQP2Dmaz48VLOZ (1439 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 5Z0DzAZoZemOvw0BV5T9Zn (1440 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 6acOiPffAMv8P5NszUtGxz (1441 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 1G5qxbVidO8WkzbT96Yu9x (1442 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 5Gi7vMlhgJKmsUsUD6tIcC (1443 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 5ANMEFK0IfDxSsyOKkjjaz (1444 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 1NAK5NKKo93nopiD2Kv0ki (1445 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 2cvf5GkuWK2yB1Ekx8P1K1 (1446 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 0ku8HtqmnCNR6aw5VBDfdT (1447 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 7gdyUtpTRb1AQycam7f2D6 (1448 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 3w3dj776WGCUAXi0zmHxTS (1449 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 3oAIxp90A0o8dYprVCaiyF (1450 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 5jhrc3t8YDrMUuCDywcsO0 (1451 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 61hjUP2XBA2Qe5ptbo217J (1452 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 41rrrTrR2Mo1lV6LXjT0BW (1453 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 12CfO2RyPn5xmAi7LK1iAE (1454 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 5VQEkSA1JhDnuSP0RLcyBm (1455 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 3iZO6gCQtEcEcCoBSQTsUu (1456 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 32KBExdswygAkJGWtjf0I3 (1457 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 1F8XWBRc69THp1hS1nDRU9 (1458 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 6P07GFpiXCi1vVwHzIlsoM (1459 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 4DA3J8uO9hZY2Y9w46lW9M (1460 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 2WvBTKoWDO1ytM5OBvhkl1 (1461 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 0AaOJsb0OfGkUNgUIcGDdD (1462 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 4rd2lpiICBxmnuallJlTNW (1463 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 4N6gt8KPjcfgoF9ykQAh5F (1464 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 2Gsgir8VirzsHnrv994Je2 (1465 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 3j3mhsTaPbjkcBkXzZwKgR (1466 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 1htQpnUIWKAiJ3e65f5AnS (1467 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 732dJDUNglsXbuaaeB7Gzk (1468 / 6613)...
# No existing track data found. Starting fresh.
# Fetched 1 tracks (offset: 0).
# Fetching 0LAiZX8DFFLbCnZYxailon (1469 / 6613)...
# No existing track data found. Starting fresh.

# %%
def fetch_tracks_details(
    track_ids: list[str],
    output_csv_path: str,
    sp: spotipy.Spotify,
    executor: ApiExecutor,
    batch_size: int = 50,
) -> pd.DataFrame:
    """
    Fetch track details in batches using the Spotify /tracks API.
    
    Args:
        track_ids (List[str]): List of track IDs to query.
        output_csv_path (str): Path to save the track details.
        sp (spotipy.Spotify): Spotify client instance.
        executor (ApiExecutor): API executor for rate limiting and retries.
        batch_size (int): Number of track IDs to query per API call (max 50).
    
    Returns:
        pd.DataFrame: A DataFrame containing track details.
    """
    # Prepare to store track data
    track_data_list = []
    
    # Batch processing
    for i in range(0, len(track_ids), batch_size):
        batch_ids = track_ids[i:i + batch_size]
        print(f"Fetching batch {i // batch_size + 1} of {len(track_ids) // batch_size + 1}")
        batch_track_datas = []
        try:
            # Fetch track details for the batch
            track_details = executor.execute_request(
                lambda: sp.tracks(batch_ids)
            )
            
            for track in track_details['tracks']:
                track_data = {
                    'id': track['id'],
                    'popularity': track.get('popularity', 0),
                    'isrc': track['external_ids'].get('isrc', None),
                    'updated_at': datetime.now(timezone.utc)
                }
                track_data_list.append(track_data)
                batch_track_datas.append(track_data)
            
            # Save track data to CSV immediately
            replace_or_append_rows_in_csv(output_csv_path, track_data_list, match_by_id)
        except Exception as e:
            print(f"Error fetching batch: {e}")
            time.sleep(30)  # Backoff in case of an error
    # Return as a DataFrame
    return pd.DataFrame(track_data_list)

# %%
import pandas as pd

album_tracks_dir = './data/album_tracks'
track_info_df = pd.DataFrame()
for file_name in os.listdir(album_tracks_dir):
    file_path = os.path.join(album_tracks_dir, file_name)
    single_track_info_df = pd.read_csv(file_path)
    track_info_df = pd.concat([track_info_df, single_track_info_df], ignore_index=True)
track_info_df
# Out:
#        disc_number  track_number  duration_ms  explicit  \
# 0                1             1       198276     False
# 1                1             2       189698     False
# 2                1             3       188339     False
# 3                1             4       205751     False
# 4                1             5       186915     False
# ...            ...           ...          ...       ...
# 26635            1            17       270626     False
# 26636            1            18       332426     False
# 26637            1            19       242080     False
# 26638            1             1       219200     False
# 26639            1             2       219200     False
#
#                                                      url  \
# 0      https://open.spotify.com/track/2eh4Rl2corOdrHS...
# 1      https://open.spotify.com/track/6KUlXAg1gCPCkCT...
# 2      https://open.spotify.com/track/7ocknIa9LHTuNFB...
# 3      https://open.spotify.com/track/0bPx8YowpNi1dtw...
# 4      https://open.spotify.com/track/344Y5pjalizVER3...
# ...                                                  ...
# 26635  https://open.spotify.com/track/7iLHfjqEF9jGe3g...
# 26636  https://open.spotify.com/track/6uCPGq3jtrEjm8G...
# 26637  https://open.spotify.com/track/4xlGgKCa187ln1N...
# 26638  https://open.spotify.com/track/0eazHAdJ2hz5G2L...
# 26639  https://open.spotify.com/track/5zpczpaMZ9Yjng4...
#
#                            id  \
# 0      2eh4Rl2corOdrHSmwoIFLD
# 1      6KUlXAg1gCPCkCTCZlu4hO
# 2      7ocknIa9LHTuNFBhieGGdT
# 3      0bPx8YowpNi1dtwoSFYCXz
# 4      344Y5pjalizVER38YjdUes
# ...                       ...
# 26635  7iLHfjqEF9jGe3gMOa9HzV
# 26636  6uCPGq3jtrEjm8Gv979tLy
# 26637  4xlGgKCa187ln1Ny7xahfA
# 26638  0eazHAdJ2hz5G2LWyFewa3
# 26639  5zpczpaMZ9Yjng4aelzGZa
#
#                                                     name  is_local  \
# 0           Bad Manners Title Track (from "Bad Manners")     False
# 1      Saraayi Kududre Jhum Anthade (from "Bad Manners")     False
# 2                           Oga Oga (from "Bad Manners")     False
# 3                              Jeeva (from"Bad Manners")     False
# 4                                            I'M IN Love     False
# ...                                                  ...       ...
# 26635                                   If It's the Same     False
# 26636                                           My Story     False
# 26637       For Your Love (2007 Live Ver.) (Bonus Track)     False
# 26638                                      Hide and Seek     False
# 26639                              Hide and Seek - Inst.     False
#
#                                               artist_ids  \
# 0                             ['63gvl4egwBtz2czz3aENGa']
# 1      ['002yVW3Yn595KWy74buQ1k', '0AEPcRWWVLW0T1TLBD...
# 2      ['0nMjhemqRwrboQGcs92fh2', '3bLpM0uZQGjGyxtXgJ...
# 3      ['4s8zgh93hZcl4GbVFgdW1H', '002yVW3Yn595KWy74b...
# 4                             ['002yVW3Yn595KWy74buQ1k']
# ...                                                  ...
# 26635                         ['7AVa6rcpTQWVqgy91llPP5']
# 26636                         ['7AVa6rcpTQWVqgy91llPP5']
# 26637                         ['7AVa6rcpTQWVqgy91llPP5']
# 26638                         ['5YPW3OmiqnqnQaFjloAvA7']
# 26639                         ['5YPW3OmiqnqnQaFjloAvA7']
#
#                      album_id
# 0      000a1ThXw3yBMgqoK20rQb
# 1      000a1ThXw3yBMgqoK20rQb
# 2      000a1ThXw3yBMgqoK20rQb
# 3      000a1ThXw3yBMgqoK20rQb
# 4      000a1ThXw3yBMgqoK20rQb
# ...                       ...
# 26635  7zXb9k3ezLLT5BAgHeSleh
# 26636  7zXb9k3ezLLT5BAgHeSleh
# 26637  7zXb9k3ezLLT5BAgHeSleh
# 26638  7zZFWGDvrY7n6N8EhCT7RX
# 26639  7zZFWGDvrY7n6N8EhCT7RX
#
# [26640 rows x 10 columns]

# %%
track_info_df.to_csv('./data/spotify_track_data.csv', index=False, encoding='utf-8')

# %%
track_detail_path = './data/spotify_track_detail_data.csv'
track_ids = track_info_df['id'].drop_duplicates()
executor.requests_per_second = 0.5
filtered_track_ids = track_ids
if os.path.isfile(track_detail_path):
    track_detail_df = pd.read_csv(track_detail_path)
    filtered_track_ids = track_ids[~track_ids.isin(track_detail_df['id'])]
df = fetch_tracks_details(filtered_track_ids, track_detail_path, sp, executor)
# Out:
# Fetching batch 1 of 355
